# %% [markdown]
# # Load entities and occupations

# %%
import json
import pathlib

from tqdm.auto import tqdm


raw = []

root = pathlib.Path('/raid/lingo/dez/code/knowledge-fluidity/data/TaskBenchData/atomic')
for directory in root.glob('wiki{occupation(0)}'):
    file = directory / 'all.jsonl'
    with file.open('r') as handle:
        for line in tqdm(handle.readlines(), desc=file.parent.name):
            raw.append(json.loads(line))
# Out:
# wiki{occupation(0)}:   0%|          | 0/19600 [00:00<?, ?it/s]

# %%
raw[0]
# Out:
# {'inputs': [{'Qid': 'q14125602', 'ent_name': 'juan juarez fernandez'}],
#  'train_tgts': [{'Qid': 'q82955', 'ent_name': 'politician'}],
#  'all_tgts': [{'Qid': 'q82955', 'ent_name': 'politician'}],
#  'R': 'wiki{occupation(0)}',
#  'nl_R': 'occupation of %0%'}

# %%
import collections

occupations = [
    occ
    for occ, _ in
    collections.Counter([entity['train_tgts'][0]['ent_name'] for entity in raw]).most_common()[:150]
]
occupations
# Out:
# ['politician',
#  'association football player',
#  'actor',
#  'painter',
#  'writer',
#  'journalist',
#  'university teacher',
#  'singer',
#  'composer',
#  'cricketer',
#  'lawyer',
#  'poet',
#  'baseball player',
#  'basketball player',
#  'film director',
#  'historian',
#  'ice hockey player',
#  'american football player',
#  'athletics competitor',
#  'architect',
#  'sport cyclist',
#  'military personnel',
#  'film actor',
#  'physician',
#  'diplomat',
#  'screenwriter',
#  'musician',
#  'engineer',
#  'catholic priest',
#  'sculptor',
#  'economist',
#  'judge',
#  'officer',
#  'australian rules footballer',
#  'priest',
#  'swimmer',
#  'author',
#  'businessperson',
#  'chess player',
#  'photographer',
#  'novelist',
#  'association football manager',
#  'botanist',
#  'rugby union player',
#  'artist',
#  'theologian',
#  'badminton player',
#  'volleyball player',
#  'stage actor',
#  'entomologist',
#  'translator',
#  'tennis player',
#  'entrepreneur',
#  'singer-songwriter',
#  'mathematician',
#  'boxer',
#  'teacher',
#  'model',
#  'philosopher',
#  'television actor',
#  'television presenter',
#  'songwriter',
#  'handball player',
#  'physicist',
#  'explorer',
#  'psychologist',
#  'conductor',
#  'pianist',
#  'film producer',
#  'canoer',
#  'seiyū',
#  'amateur wrestler',
#  'chemist',
#  'jurist',
#  'linguist',
#  'playwright',
#  'association football referee',
#  'rower',
#  'trade unionist',
#  'rugby league player',
#  'figure skater',
#  'record producer',
#  'cinematographer',
#  'artistic gymnast',
#  'field hockey player',
#  'astronomer',
#  'jazz musician',
#  'comics artist',
#  'soldier',
#  'banker',
#  'opera singer',
#  'sportsperson',
#  'fencer',
#  'illustrator',
#  'zoologist',
#  'golfer',
#  'art historian',
#  'farmer',
#  'voice actor',
#  'music educator',
#  'surgeon',
#  'guitarist',
#  'yachtmaster',
#  'judoka',
#  'basketball coach',
#  'radio personality',
#  'musicologist',
#  'av idol',
#  'aviator',
#  'publisher',
#  'anthropologist',
#  'biathlete',
#  'announcer',
#  'choreographer',
#  'speed skater',
#  'educator',
#  'sociologist',
#  "children's writer",
#  'racecar driver',
#  'computer scientist',
#  'mangaka',
#  'alpine skier',
#  'psychiatrist',
#  'literary critic',
#  'missionary',
#  'mixed martial artist',
#  'geologist',
#  'beauty pageant contestant',
#  'archaeologist',
#  'sprinter',
#  'head coach',
#  'comedian',
#  'racing driver',
#  'cleric',
#  'editor',
#  'sport shooter',
#  'minister',
#  'theatre director',
#  'non-fiction writer',
#  'biologist',
#  'police officer',
#  'herpetologist',
#  'motorcycle racer',
#  'diver',
#  'visual artist',
#  'monk',
#  'tarento',
#  'rabbi',
#  'samurai',
#  'table tennis player']

# %% [markdown]
# # Create contexts

# %%
import transformers

device = 'cuda:1'
roberta = None
bart = None

# tokenizer = transformers.AutoTokenizer.from_pretrained('roberta-base')
# roberta = transformers.AutoModelForMaskedLM.from_pretrained('roberta-base').to(device)

tokenizer = transformers.BartTokenizer.from_pretrained("facebook/bart-large")
bart = transformers.BartForConditionalGeneration.from_pretrained("facebook/bart-large",
                                                                 forced_bos_token_id=0).to(device)

# %%
context_templates = (
    'A {occupation} works at a <mask>',  # Location
    'A {occupation} uses a <mask>',  # Tool
    'The job of a {occupation} is to <mask>', # Role
    'A {occupation} has a degree in <mask>',  # Training
)
context_prompts = {
    occupation: [
        template.format(occupation=occupation)
        for template in context_templates
    ]
    for occupation in occupations
}
context_prompts
# Out:
# {'politician': ['A politician works at a <mask>',
#   'A politician uses a <mask>',
#   'The job of a politician is to <mask>',
#   'A politician has a degree in <mask>'],
#  'association football player': ['A association football player works at a <mask>',
#   'A association football player uses a <mask>',
#   'The job of a association football player is to <mask>',
#   'A association football player has a degree in <mask>'],
#  'actor': ['A actor works at a <mask>',
#   'A actor uses a <mask>',
#   'The job of a actor is to <mask>',
#   'A actor has a degree in <mask>'],
#  'painter': ['A painter works at a <mask>',
#   'A painter uses a <mask>',
#   'The job of a painter is to <mask>',
#   'A painter has a degree in <mask>'],
#  'writer': ['A writer works at a <mask>',
#   'A writer uses a <mask>',
#   'The job of a writer is to <mask>',
#   'A writer has a degree in <mask>'],
#  'journalist': ['A journalist works at a <mask>',
#   'A journalist uses a <mask>',
#   'The job of a journalist is to <mask>',
#   'A journalist has a degree in <mask>'],
#  'university teacher': ['A university teacher works at a <mask>',
#   'A university teacher uses a <mask>',
#   'The job of a university teacher is to <mask>',
#   'A university teacher has a degree in <mask>'],
#  'singer': ['A singer works at a <mask>',
#   'A singer uses a <mask>',
#   'The job of a singer is to <mask>',
#   'A singer has a degree in <mask>'],
#  'composer': ['A composer works at a <mask>',
#   'A composer uses a <mask>',
#   'The job of a composer is to <mask>',
#   'A composer has a degree in <mask>'],
#  'cricketer': ['A cricketer works at a <mask>',
#   'A cricketer uses a <mask>',
#   'The job of a cricketer is to <mask>',
#   'A cricketer has a degree in <mask>'],
#  'lawyer': ['A lawyer works at a <mask>',
#   'A lawyer uses a <mask>',
#   'The job of a lawyer is to <mask>',
#   'A lawyer has a degree in <mask>'],
#  'poet': ['A poet works at a <mask>',
#   'A poet uses a <mask>',
#   'The job of a poet is to <mask>',
#   'A poet has a degree in <mask>'],
#  'baseball player': ['A baseball player works at a <mask>',
#   'A baseball player uses a <mask>',
#   'The job of a baseball player is to <mask>',
#   'A baseball player has a degree in <mask>'],
#  'basketball player': ['A basketball player works at a <mask>',
#   'A basketball player uses a <mask>',
#   'The job of a basketball player is to <mask>',
#   'A basketball player has a degree in <mask>'],
#  'film director': ['A film director works at a <mask>',
#   'A film director uses a <mask>',
#   'The job of a film director is to <mask>',
#   'A film director has a degree in <mask>'],
#  'historian': ['A historian works at a <mask>',
#   'A historian uses a <mask>',
#   'The job of a historian is to <mask>',
#   'A historian has a degree in <mask>'],
#  'ice hockey player': ['A ice hockey player works at a <mask>',
#   'A ice hockey player uses a <mask>',
#   'The job of a ice hockey player is to <mask>',
#   'A ice hockey player has a degree in <mask>'],
#  'american football player': ['A american football player works at a <mask>',
#   'A american football player uses a <mask>',
#   'The job of a american football player is to <mask>',
#   'A american football player has a degree in <mask>'],
#  'athletics competitor': ['A athletics competitor works at a <mask>',
#   'A athletics competitor uses a <mask>',
#   'The job of a athletics competitor is to <mask>',
#   'A athletics competitor has a degree in <mask>'],
#  'architect': ['A architect works at a <mask>',
#   'A architect uses a <mask>',
#   'The job of a architect is to <mask>',
#   'A architect has a degree in <mask>'],
#  'sport cyclist': ['A sport cyclist works at a <mask>',
#   'A sport cyclist uses a <mask>',
#   'The job of a sport cyclist is to <mask>',
#   'A sport cyclist has a degree in <mask>'],
#  'military personnel': ['A military personnel works at a <mask>',
#   'A military personnel uses a <mask>',
#   'The job of a military personnel is to <mask>',
#   'A military personnel has a degree in <mask>'],
#  'film actor': ['A film actor works at a <mask>',
#   'A film actor uses a <mask>',
#   'The job of a film actor is to <mask>',
#   'A film actor has a degree in <mask>'],
#  'physician': ['A physician works at a <mask>',
#   'A physician uses a <mask>',
#   'The job of a physician is to <mask>',
#   'A physician has a degree in <mask>'],
#  'diplomat': ['A diplomat works at a <mask>',
#   'A diplomat uses a <mask>',
#   'The job of a diplomat is to <mask>',
#   'A diplomat has a degree in <mask>'],
#  'screenwriter': ['A screenwriter works at a <mask>',
#   'A screenwriter uses a <mask>',
#   'The job of a screenwriter is to <mask>',
#   'A screenwriter has a degree in <mask>'],
#  'musician': ['A musician works at a <mask>',
#   'A musician uses a <mask>',
#   'The job of a musician is to <mask>',
#   'A musician has a degree in <mask>'],
#  'engineer': ['A engineer works at a <mask>',
#   'A engineer uses a <mask>',
#   'The job of a engineer is to <mask>',
#   'A engineer has a degree in <mask>'],
#  'catholic priest': ['A catholic priest works at a <mask>',
#   'A catholic priest uses a <mask>',
#   'The job of a catholic priest is to <mask>',
#   'A catholic priest has a degree in <mask>'],
#  'sculptor': ['A sculptor works at a <mask>',
#   'A sculptor uses a <mask>',
#   'The job of a sculptor is to <mask>',
#   'A sculptor has a degree in <mask>'],
#  'economist': ['A economist works at a <mask>',
#   'A economist uses a <mask>',
#   'The job of a economist is to <mask>',
#   'A economist has a degree in <mask>'],
#  'judge': ['A judge works at a <mask>',
#   'A judge uses a <mask>',
#   'The job of a judge is to <mask>',
#   'A judge has a degree in <mask>'],
#  'officer': ['A officer works at a <mask>',
#   'A officer uses a <mask>',
#   'The job of a officer is to <mask>',
#   'A officer has a degree in <mask>'],
#  'australian rules footballer': ['A australian rules footballer works at a <mask>',
#   'A australian rules footballer uses a <mask>',
#   'The job of a australian rules footballer is to <mask>',
#   'A australian rules footballer has a degree in <mask>'],
#  'priest': ['A priest works at a <mask>',
#   'A priest uses a <mask>',
#   'The job of a priest is to <mask>',
#   'A priest has a degree in <mask>'],
#  'swimmer': ['A swimmer works at a <mask>',
#   'A swimmer uses a <mask>',
#   'The job of a swimmer is to <mask>',
#   'A swimmer has a degree in <mask>'],
#  'author': ['A author works at a <mask>',
#   'A author uses a <mask>',
#   'The job of a author is to <mask>',
#   'A author has a degree in <mask>'],
#  'businessperson': ['A businessperson works at a <mask>',
#   'A businessperson uses a <mask>',
#   'The job of a businessperson is to <mask>',
#   'A businessperson has a degree in <mask>'],
#  'chess player': ['A chess player works at a <mask>',
#   'A chess player uses a <mask>',
#   'The job of a chess player is to <mask>',
#   'A chess player has a degree in <mask>'],
#  'photographer': ['A photographer works at a <mask>',
#   'A photographer uses a <mask>',
#   'The job of a photographer is to <mask>',
#   'A photographer has a degree in <mask>'],
#  'novelist': ['A novelist works at a <mask>',
#   'A novelist uses a <mask>',
#   'The job of a novelist is to <mask>',
#   'A novelist has a degree in <mask>'],
#  'association football manager': ['A association football manager works at a <mask>',
#   'A association football manager uses a <mask>',
#   'The job of a association football manager is to <mask>',
#   'A association football manager has a degree in <mask>'],
#  'botanist': ['A botanist works at a <mask>',
#   'A botanist uses a <mask>',
#   'The job of a botanist is to <mask>',
#   'A botanist has a degree in <mask>'],
#  'rugby union player': ['A rugby union player works at a <mask>',
#   'A rugby union player uses a <mask>',
#   'The job of a rugby union player is to <mask>',
#   'A rugby union player has a degree in <mask>'],
#  'artist': ['A artist works at a <mask>',
#   'A artist uses a <mask>',
#   'The job of a artist is to <mask>',
#   'A artist has a degree in <mask>'],
#  'theologian': ['A theologian works at a <mask>',
#   'A theologian uses a <mask>',
#   'The job of a theologian is to <mask>',
#   'A theologian has a degree in <mask>'],
#  'badminton player': ['A badminton player works at a <mask>',
#   'A badminton player uses a <mask>',
#   'The job of a badminton player is to <mask>',
#   'A badminton player has a degree in <mask>'],
#  'volleyball player': ['A volleyball player works at a <mask>',
#   'A volleyball player uses a <mask>',
#   'The job of a volleyball player is to <mask>',
#   'A volleyball player has a degree in <mask>'],
#  'stage actor': ['A stage actor works at a <mask>',
#   'A stage actor uses a <mask>',
#   'The job of a stage actor is to <mask>',
#   'A stage actor has a degree in <mask>'],
#  'entomologist': ['A entomologist works at a <mask>',
#   'A entomologist uses a <mask>',
#   'The job of a entomologist is to <mask>',
#   'A entomologist has a degree in <mask>'],
#  'translator': ['A translator works at a <mask>',
#   'A translator uses a <mask>',
#   'The job of a translator is to <mask>',
#   'A translator has a degree in <mask>'],
#  'tennis player': ['A tennis player works at a <mask>',
#   'A tennis player uses a <mask>',
#   'The job of a tennis player is to <mask>',
#   'A tennis player has a degree in <mask>'],
#  'entrepreneur': ['A entrepreneur works at a <mask>',
#   'A entrepreneur uses a <mask>',
#   'The job of a entrepreneur is to <mask>',
#   'A entrepreneur has a degree in <mask>'],
#  'singer-songwriter': ['A singer-songwriter works at a <mask>',
#   'A singer-songwriter uses a <mask>',
#   'The job of a singer-songwriter is to <mask>',
#   'A singer-songwriter has a degree in <mask>'],
#  'mathematician': ['A mathematician works at a <mask>',
#   'A mathematician uses a <mask>',
#   'The job of a mathematician is to <mask>',
#   'A mathematician has a degree in <mask>'],
#  'boxer': ['A boxer works at a <mask>',
#   'A boxer uses a <mask>',
#   'The job of a boxer is to <mask>',
#   'A boxer has a degree in <mask>'],
#  'teacher': ['A teacher works at a <mask>',
#   'A teacher uses a <mask>',
#   'The job of a teacher is to <mask>',
#   'A teacher has a degree in <mask>'],
#  'model': ['A model works at a <mask>',
#   'A model uses a <mask>',
#   'The job of a model is to <mask>',
#   'A model has a degree in <mask>'],
#  'philosopher': ['A philosopher works at a <mask>',
#   'A philosopher uses a <mask>',
#   'The job of a philosopher is to <mask>',
#   'A philosopher has a degree in <mask>'],
#  'television actor': ['A television actor works at a <mask>',
#   'A television actor uses a <mask>',
#   'The job of a television actor is to <mask>',
#   'A television actor has a degree in <mask>'],
#  'television presenter': ['A television presenter works at a <mask>',
#   'A television presenter uses a <mask>',
#   'The job of a television presenter is to <mask>',
#   'A television presenter has a degree in <mask>'],
#  'songwriter': ['A songwriter works at a <mask>',
#   'A songwriter uses a <mask>',
#   'The job of a songwriter is to <mask>',
#   'A songwriter has a degree in <mask>'],
#  'handball player': ['A handball player works at a <mask>',
#   'A handball player uses a <mask>',
#   'The job of a handball player is to <mask>',
#   'A handball player has a degree in <mask>'],
#  'physicist': ['A physicist works at a <mask>',
#   'A physicist uses a <mask>',
#   'The job of a physicist is to <mask>',
#   'A physicist has a degree in <mask>'],
#  'explorer': ['A explorer works at a <mask>',
#   'A explorer uses a <mask>',
#   'The job of a explorer is to <mask>',
#   'A explorer has a degree in <mask>'],
#  'psychologist': ['A psychologist works at a <mask>',
#   'A psychologist uses a <mask>',
#   'The job of a psychologist is to <mask>',
#   'A psychologist has a degree in <mask>'],
#  'conductor': ['A conductor works at a <mask>',
#   'A conductor uses a <mask>',
#   'The job of a conductor is to <mask>',
#   'A conductor has a degree in <mask>'],
#  'pianist': ['A pianist works at a <mask>',
#   'A pianist uses a <mask>',
#   'The job of a pianist is to <mask>',
#   'A pianist has a degree in <mask>'],
#  'film producer': ['A film producer works at a <mask>',
#   'A film producer uses a <mask>',
#   'The job of a film producer is to <mask>',
#   'A film producer has a degree in <mask>'],
#  'canoer': ['A canoer works at a <mask>',
#   'A canoer uses a <mask>',
#   'The job of a canoer is to <mask>',
#   'A canoer has a degree in <mask>'],
#  'seiyū': ['A seiyū works at a <mask>',
#   'A seiyū uses a <mask>',
#   'The job of a seiyū is to <mask>',
#   'A seiyū has a degree in <mask>'],
#  'amateur wrestler': ['A amateur wrestler works at a <mask>',
#   'A amateur wrestler uses a <mask>',
#   'The job of a amateur wrestler is to <mask>',
#   'A amateur wrestler has a degree in <mask>'],
#  'chemist': ['A chemist works at a <mask>',
#   'A chemist uses a <mask>',
#   'The job of a chemist is to <mask>',
#   'A chemist has a degree in <mask>'],
#  'jurist': ['A jurist works at a <mask>',
#   'A jurist uses a <mask>',
#   'The job of a jurist is to <mask>',
#   'A jurist has a degree in <mask>'],
#  'linguist': ['A linguist works at a <mask>',
#   'A linguist uses a <mask>',
#   'The job of a linguist is to <mask>',
#   'A linguist has a degree in <mask>'],
#  'playwright': ['A playwright works at a <mask>',
#   'A playwright uses a <mask>',
#   'The job of a playwright is to <mask>',
#   'A playwright has a degree in <mask>'],
#  'association football referee': ['A association football referee works at a <mask>',
#   'A association football referee uses a <mask>',
#   'The job of a association football referee is to <mask>',
#   'A association football referee has a degree in <mask>'],
#  'rower': ['A rower works at a <mask>',
#   'A rower uses a <mask>',
#   'The job of a rower is to <mask>',
#   'A rower has a degree in <mask>'],
#  'trade unionist': ['A trade unionist works at a <mask>',
#   'A trade unionist uses a <mask>',
#   'The job of a trade unionist is to <mask>',
#   'A trade unionist has a degree in <mask>'],
#  'rugby league player': ['A rugby league player works at a <mask>',
#   'A rugby league player uses a <mask>',
#   'The job of a rugby league player is to <mask>',
#   'A rugby league player has a degree in <mask>'],
#  'figure skater': ['A figure skater works at a <mask>',
#   'A figure skater uses a <mask>',
#   'The job of a figure skater is to <mask>',
#   'A figure skater has a degree in <mask>'],
#  'record producer': ['A record producer works at a <mask>',
#   'A record producer uses a <mask>',
#   'The job of a record producer is to <mask>',
#   'A record producer has a degree in <mask>'],
#  'cinematographer': ['A cinematographer works at a <mask>',
#   'A cinematographer uses a <mask>',
#   'The job of a cinematographer is to <mask>',
#   'A cinematographer has a degree in <mask>'],
#  'artistic gymnast': ['A artistic gymnast works at a <mask>',
#   'A artistic gymnast uses a <mask>',
#   'The job of a artistic gymnast is to <mask>',
#   'A artistic gymnast has a degree in <mask>'],
#  'field hockey player': ['A field hockey player works at a <mask>',
#   'A field hockey player uses a <mask>',
#   'The job of a field hockey player is to <mask>',
#   'A field hockey player has a degree in <mask>'],
#  'astronomer': ['A astronomer works at a <mask>',
#   'A astronomer uses a <mask>',
#   'The job of a astronomer is to <mask>',
#   'A astronomer has a degree in <mask>'],
#  'jazz musician': ['A jazz musician works at a <mask>',
#   'A jazz musician uses a <mask>',
#   'The job of a jazz musician is to <mask>',
#   'A jazz musician has a degree in <mask>'],
#  'comics artist': ['A comics artist works at a <mask>',
#   'A comics artist uses a <mask>',
#   'The job of a comics artist is to <mask>',
#   'A comics artist has a degree in <mask>'],
#  'soldier': ['A soldier works at a <mask>',
#   'A soldier uses a <mask>',
#   'The job of a soldier is to <mask>',
#   'A soldier has a degree in <mask>'],
#  'banker': ['A banker works at a <mask>',
#   'A banker uses a <mask>',
#   'The job of a banker is to <mask>',
#   'A banker has a degree in <mask>'],
#  'opera singer': ['A opera singer works at a <mask>',
#   'A opera singer uses a <mask>',
#   'The job of a opera singer is to <mask>',
#   'A opera singer has a degree in <mask>'],
#  'sportsperson': ['A sportsperson works at a <mask>',
#   'A sportsperson uses a <mask>',
#   'The job of a sportsperson is to <mask>',
#   'A sportsperson has a degree in <mask>'],
#  'fencer': ['A fencer works at a <mask>',
#   'A fencer uses a <mask>',
#   'The job of a fencer is to <mask>',
#   'A fencer has a degree in <mask>'],
#  'illustrator': ['A illustrator works at a <mask>',
#   'A illustrator uses a <mask>',
#   'The job of a illustrator is to <mask>',
#   'A illustrator has a degree in <mask>'],
#  'zoologist': ['A zoologist works at a <mask>',
#   'A zoologist uses a <mask>',
#   'The job of a zoologist is to <mask>',
#   'A zoologist has a degree in <mask>'],
#  'golfer': ['A golfer works at a <mask>',
#   'A golfer uses a <mask>',
#   'The job of a golfer is to <mask>',
#   'A golfer has a degree in <mask>'],
#  'art historian': ['A art historian works at a <mask>',
#   'A art historian uses a <mask>',
#   'The job of a art historian is to <mask>',
#   'A art historian has a degree in <mask>'],
#  'farmer': ['A farmer works at a <mask>',
#   'A farmer uses a <mask>',
#   'The job of a farmer is to <mask>',
#   'A farmer has a degree in <mask>'],
#  'voice actor': ['A voice actor works at a <mask>',
#   'A voice actor uses a <mask>',
#   'The job of a voice actor is to <mask>',
#   'A voice actor has a degree in <mask>'],
#  'music educator': ['A music educator works at a <mask>',
#   'A music educator uses a <mask>',
#   'The job of a music educator is to <mask>',
#   'A music educator has a degree in <mask>'],
#  'surgeon': ['A surgeon works at a <mask>',
#   'A surgeon uses a <mask>',
#   'The job of a surgeon is to <mask>',
#   'A surgeon has a degree in <mask>'],
#  'guitarist': ['A guitarist works at a <mask>',
#   'A guitarist uses a <mask>',
#   'The job of a guitarist is to <mask>',
#   'A guitarist has a degree in <mask>'],
#  'yachtmaster': ['A yachtmaster works at a <mask>',
#   'A yachtmaster uses a <mask>',
#   'The job of a yachtmaster is to <mask>',
#   'A yachtmaster has a degree in <mask>'],
#  'judoka': ['A judoka works at a <mask>',
#   'A judoka uses a <mask>',
#   'The job of a judoka is to <mask>',
#   'A judoka has a degree in <mask>'],
#  'basketball coach': ['A basketball coach works at a <mask>',
#   'A basketball coach uses a <mask>',
#   'The job of a basketball coach is to <mask>',
#   'A basketball coach has a degree in <mask>'],
#  'radio personality': ['A radio personality works at a <mask>',
#   'A radio personality uses a <mask>',
#   'The job of a radio personality is to <mask>',
#   'A radio personality has a degree in <mask>'],
#  'musicologist': ['A musicologist works at a <mask>',
#   'A musicologist uses a <mask>',
#   'The job of a musicologist is to <mask>',
#   'A musicologist has a degree in <mask>'],
#  'av idol': ['A av idol works at a <mask>',
#   'A av idol uses a <mask>',
#   'The job of a av idol is to <mask>',
#   'A av idol has a degree in <mask>'],
#  'aviator': ['A aviator works at a <mask>',
#   'A aviator uses a <mask>',
#   'The job of a aviator is to <mask>',
#   'A aviator has a degree in <mask>'],
#  'publisher': ['A publisher works at a <mask>',
#   'A publisher uses a <mask>',
#   'The job of a publisher is to <mask>',
#   'A publisher has a degree in <mask>'],
#  'anthropologist': ['A anthropologist works at a <mask>',
#   'A anthropologist uses a <mask>',
#   'The job of a anthropologist is to <mask>',
#   'A anthropologist has a degree in <mask>'],
#  'biathlete': ['A biathlete works at a <mask>',
#   'A biathlete uses a <mask>',
#   'The job of a biathlete is to <mask>',
#   'A biathlete has a degree in <mask>'],
#  'announcer': ['A announcer works at a <mask>',
#   'A announcer uses a <mask>',
#   'The job of a announcer is to <mask>',
#   'A announcer has a degree in <mask>'],
#  'choreographer': ['A choreographer works at a <mask>',
#   'A choreographer uses a <mask>',
#   'The job of a choreographer is to <mask>',
#   'A choreographer has a degree in <mask>'],
#  'speed skater': ['A speed skater works at a <mask>',
#   'A speed skater uses a <mask>',
#   'The job of a speed skater is to <mask>',
#   'A speed skater has a degree in <mask>'],
#  'educator': ['A educator works at a <mask>',
#   'A educator uses a <mask>',
#   'The job of a educator is to <mask>',
#   'A educator has a degree in <mask>'],
#  'sociologist': ['A sociologist works at a <mask>',
#   'A sociologist uses a <mask>',
#   'The job of a sociologist is to <mask>',
#   'A sociologist has a degree in <mask>'],
#  "children's writer": ["A children's writer works at a <mask>",
#   "A children's writer uses a <mask>",
#   "The job of a children's writer is to <mask>",
#   "A children's writer has a degree in <mask>"],
#  'racecar driver': ['A racecar driver works at a <mask>',
#   'A racecar driver uses a <mask>',
#   'The job of a racecar driver is to <mask>',
#   'A racecar driver has a degree in <mask>'],
#  'computer scientist': ['A computer scientist works at a <mask>',
#   'A computer scientist uses a <mask>',
#   'The job of a computer scientist is to <mask>',
#   'A computer scientist has a degree in <mask>'],
#  'mangaka': ['A mangaka works at a <mask>',
#   'A mangaka uses a <mask>',
#   'The job of a mangaka is to <mask>',
#   'A mangaka has a degree in <mask>'],
#  'alpine skier': ['A alpine skier works at a <mask>',
#   'A alpine skier uses a <mask>',
#   'The job of a alpine skier is to <mask>',
#   'A alpine skier has a degree in <mask>'],
#  'psychiatrist': ['A psychiatrist works at a <mask>',
#   'A psychiatrist uses a <mask>',
#   'The job of a psychiatrist is to <mask>',
#   'A psychiatrist has a degree in <mask>'],
#  'literary critic': ['A literary critic works at a <mask>',
#   'A literary critic uses a <mask>',
#   'The job of a literary critic is to <mask>',
#   'A literary critic has a degree in <mask>'],
#  'missionary': ['A missionary works at a <mask>',
#   'A missionary uses a <mask>',
#   'The job of a missionary is to <mask>',
#   'A missionary has a degree in <mask>'],
#  'mixed martial artist': ['A mixed martial artist works at a <mask>',
#   'A mixed martial artist uses a <mask>',
#   'The job of a mixed martial artist is to <mask>',
#   'A mixed martial artist has a degree in <mask>'],
#  'geologist': ['A geologist works at a <mask>',
#   'A geologist uses a <mask>',
#   'The job of a geologist is to <mask>',
#   'A geologist has a degree in <mask>'],
#  'beauty pageant contestant': ['A beauty pageant contestant works at a <mask>',
#   'A beauty pageant contestant uses a <mask>',
#   'The job of a beauty pageant contestant is to <mask>',
#   'A beauty pageant contestant has a degree in <mask>'],
#  'archaeologist': ['A archaeologist works at a <mask>',
#   'A archaeologist uses a <mask>',
#   'The job of a archaeologist is to <mask>',
#   'A archaeologist has a degree in <mask>'],
#  'sprinter': ['A sprinter works at a <mask>',
#   'A sprinter uses a <mask>',
#   'The job of a sprinter is to <mask>',
#   'A sprinter has a degree in <mask>'],
#  'head coach': ['A head coach works at a <mask>',
#   'A head coach uses a <mask>',
#   'The job of a head coach is to <mask>',
#   'A head coach has a degree in <mask>'],
#  'comedian': ['A comedian works at a <mask>',
#   'A comedian uses a <mask>',
#   'The job of a comedian is to <mask>',
#   'A comedian has a degree in <mask>'],
#  'racing driver': ['A racing driver works at a <mask>',
#   'A racing driver uses a <mask>',
#   'The job of a racing driver is to <mask>',
#   'A racing driver has a degree in <mask>'],
#  'cleric': ['A cleric works at a <mask>',
#   'A cleric uses a <mask>',
#   'The job of a cleric is to <mask>',
#   'A cleric has a degree in <mask>'],
#  'editor': ['A editor works at a <mask>',
#   'A editor uses a <mask>',
#   'The job of a editor is to <mask>',
#   'A editor has a degree in <mask>'],
#  'sport shooter': ['A sport shooter works at a <mask>',
#   'A sport shooter uses a <mask>',
#   'The job of a sport shooter is to <mask>',
#   'A sport shooter has a degree in <mask>'],
#  'minister': ['A minister works at a <mask>',
#   'A minister uses a <mask>',
#   'The job of a minister is to <mask>',
#   'A minister has a degree in <mask>'],
#  'theatre director': ['A theatre director works at a <mask>',
#   'A theatre director uses a <mask>',
#   'The job of a theatre director is to <mask>',
#   'A theatre director has a degree in <mask>'],
#  'non-fiction writer': ['A non-fiction writer works at a <mask>',
#   'A non-fiction writer uses a <mask>',
#   'The job of a non-fiction writer is to <mask>',
#   'A non-fiction writer has a degree in <mask>'],
#  'biologist': ['A biologist works at a <mask>',
#   'A biologist uses a <mask>',
#   'The job of a biologist is to <mask>',
#   'A biologist has a degree in <mask>'],
#  'police officer': ['A police officer works at a <mask>',
#   'A police officer uses a <mask>',
#   'The job of a police officer is to <mask>',
#   'A police officer has a degree in <mask>'],
#  'herpetologist': ['A herpetologist works at a <mask>',
#   'A herpetologist uses a <mask>',
#   'The job of a herpetologist is to <mask>',
#   'A herpetologist has a degree in <mask>'],
#  'motorcycle racer': ['A motorcycle racer works at a <mask>',
#   'A motorcycle racer uses a <mask>',
#   'The job of a motorcycle racer is to <mask>',
#   'A motorcycle racer has a degree in <mask>'],
#  'diver': ['A diver works at a <mask>',
#   'A diver uses a <mask>',
#   'The job of a diver is to <mask>',
#   'A diver has a degree in <mask>'],
#  'visual artist': ['A visual artist works at a <mask>',
#   'A visual artist uses a <mask>',
#   'The job of a visual artist is to <mask>',
#   'A visual artist has a degree in <mask>'],
#  'monk': ['A monk works at a <mask>',
#   'A monk uses a <mask>',
#   'The job of a monk is to <mask>',
#   'A monk has a degree in <mask>'],
#  'tarento': ['A tarento works at a <mask>',
#   'A tarento uses a <mask>',
#   'The job of a tarento is to <mask>',
#   'A tarento has a degree in <mask>'],
#  'rabbi': ['A rabbi works at a <mask>',
#   'A rabbi uses a <mask>',
#   'The job of a rabbi is to <mask>',
#   'A rabbi has a degree in <mask>'],
#  'samurai': ['A samurai works at a <mask>',
#   'A samurai uses a <mask>',
#   'The job of a samurai is to <mask>',
#   'A samurai has a degree in <mask>'],
#  'table tennis player': ['A table tennis player works at a <mask>',
#   'A table tennis player uses a <mask>',
#   'The job of a table tennis player is to <mask>',
#   'A table tennis player has a degree in <mask>']}

# %%
from collections import defaultdict

import torch
import torch.utils.data
from tqdm.auto import tqdm


loader = torch.utils.data.DataLoader(tuple(context_prompts.items()), batch_size=32)

fillers = defaultdict(list)
for occs, prompts_by_kind in tqdm(loader):
    for prompts in prompts_by_kind:
        inputs = tokenizer(list(prompts), return_tensors='pt', padding='longest').to(device)
        if roberta is not None:
            with torch.inference_mode():
                outputs = roberta(**inputs)
            indices = inputs.attention_mask.sum(dim=-1) - 3
            logits = outputs.logits[torch.arange(len(indices)), indices.squeeze()]
            predictions = logits.argmax(dim=-1)
            assert len(occs) == len(predictions)
            for occupation, ids in zip(occs, predictions):
                token = tokenizer.decode(ids.squeeze().tolist()).strip()
                fillers[occupation].append(token)
        else:
            assert bart is not None
            with torch.inference_mode():
                outputs = bart.generate(**inputs)

            indices = inputs.attention_mask.sum(dim=-1) - 1
            strings = []
            for ids, start in zip(outputs, indices):
                string = tokenizer.decode(ids[start:], skip_special_tokens=True).strip()
                strings.append(string)
            assert len(occs) == len(strings)
            for occupation, string in zip(occs, strings):
                fillers[occupation].append(string.strip(' .;:'))

fillers
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# defaultdict(list,
#             {'politician': ['political party',
#               'pseudonym',
#               'govern',
#               'political science'],
#              'association football player': ['football club',
#               'number plate',
#               'score goals',
#               'law'],
#              'actor': ['theatre', 'pseudonym', 'entertain', 'acting'],
#              'painter': ['studio', 'brush', 'paint', 'painting'],
#              'writer': ['distance', 'pseudonym', 'write', 'journalism'],
#              'journalist': ['newspaper',
#               'pseudonym',
#               'tell the truth',
#               'journalism'],
#              'university teacher': ['university',
#               'computer',
#               'teach',
#               'education'],
#              'singer': ['restaurant', 'microphone', 'entertain', 'music'],
#              'composer': ['distance',
#               'synthesizer',
#               'make music',
#               'composition'],
#              'cricketer': ['cricket ground', 'bat', 'score runs', 'cricket'],
#              'lawyer': ['law firm', 'lawyer', 'represent you', 'law'],
#              'poet': ['distance', 'pseudonym', 'write', 'poetry'],
#              'baseball player': ['restaurant',
#               'baseball bat',
#               'play baseball',
#               'baseball'],
#              'basketball player': ['restaurant',
#               'wheelchair',
#               'score',
#               'sports science'],
#              'film director': ['film studio',
#               'pseudonym',
#               'tell a story',
#               'film'],
#              'historian': ['museum',
#               'dictionary',
#               'tell the truth',
#               'history'],
#              'ice hockey player': ['restaurant',
#               'stick',
#               'score goals',
#               'sports science'],
#              'american football player': ['restaurant',
#               'wheelchair',
#               'win',
#               'psychology'],
#              'athletics competitor': ['school',
#               'wheelchair',
#               'win',
#               'athletics'],
#              'architect': ['construction site',
#               'computer',
#               'design',
#               'architecture'],
#              'sport cyclist': ['bicycle shop',
#               'bicycle',
#               'win',
#               'sport science'],
#              'military personnel': ['checkpoint',
#               'gun',
#               'protect the country',
#               'military science'],
#              'film actor': ['film studio',
#               'prosthetic limb',
#               'entertain',
#               'acting'],
#              'physician': ['hospital', 'computer', 'treat', 'medicine'],
#              'diplomat': ['desk', 'translator', 'be a diplomat', 'diplomacy'],
#              'screenwriter': ['film studio',
#               'pseudonym',
#               'tell a story',
#               'screenwriting'],
#              'musician': ['recording studio',
#               'synthesizer',
#               'entertain',
#               'music'],
#              'engineer': ['company',
#               'calculator',
#               'make things work',
#               'engineering'],
#              'catholic priest': ['church', 'diaphragm', 'love', 'theology'],
#              'sculptor': ['studio', 'wheel', 'create', 'sculpture'],
#              'economist': ['bank', 'calculator', 'predict', 'economics'],
#              'judge': ['courthouse', 'computer', 'decide', 'law'],
#              'officer': ['police station', 'stun gun', 'protect', 'law'],
#              'australian rules footballer': ['hospital',
#               'wheelchair',
#               'win',
#               'economics'],
#              'priest': ['church', 'diaphragm', 'love', 'theology'],
#              'swimmer': ['pool', 'diving board', 'swim', 'swimming'],
#              'author': ['time', 'pseudonym', 'write', 'journalism'],
#              'businessperson': ['business',
#               'pseudonym',
#               'make money',
#               'business administration'],
#              'chess player': ['chessboard',
#               'chessboard',
#               'play chess',
#               'chess'],
#              'photographer': ['studio',
#               'tripod',
#               'capture the moment',
#               'photography'],
#              'novelist': ['loss', 'pseudonym', 'write', 'English literature'],
#              'association football manager': ['football club',
#               'number system',
#               'manage a team',
#               'football administration'],
#              'botanist': ['botanical garden',
#               'microscope',
#               'study plants',
#               'botany'],
#              'rugby union player': ['hospital',
#               'rugby ball',
#               'play rugby',
#               'sports science'],
#              'artist': ['studio', 'computer', 'create', 'art'],
#              'theologian': ['church', 'metaphor', 'teach', 'theology'],
#              'badminton player': ['hotel',
#               'shuttlecock',
#               'win',
#               'sports science'],
#              'volleyball player': ['restaurant', 'net', 'serve', 'volleyball'],
#              'stage actor': ['theatre', 'stage name', 'entertain', 'acting'],
#              'entomologist': ['museum',
#               'microscope',
#               'study insects',
#               'entomology'],
#              'translator': ['distance',
#               'translator',
#               'translate',
#               'translation'],
#              'tennis player': ['tennis court', 'racket', 'win', 'tennis'],
#              'entrepreneur': ['company',
#               'computer',
#               'make money',
#               'economics'],
#              'singer-songwriter': ['coffee shop',
#               'pseudonym',
#               'entertain',
#               'music'],
#              'mathematician': ['university',
#               'formula',
#               'solve problems',
#               'mathematics'],
#              'boxer': ['boxing gym', 'belt', 'win', 'boxing'],
#              'teacher': ['school', 'computer', 'teach', 'education'],
#              'model': ['distance', 'model', 'be a model', 'modeling'],
#              'philosopher': ['distance',
#               'metaphor',
#               'understand',
#               'philosophy'],
#              'television actor': ['television studio',
#               'pseudonym',
#               'entertain',
#               'acting'],
#              'television presenter': ['television station',
#               'microphone',
#               'entertain',
#               'journalism'],
#              'songwriter': ['record label', 'pseudonym', 'write', 'music'],
#              'handball player': ['gym', 'stick', 'win', 'handball'],
#              'physicist': ['university',
#               'microscope',
#               'understand',
#               'physics'],
#              'explorer': ['glacier', 'compass', 'discover', 'archaeology'],
#              'psychologist': ['hospital', 'computer', 'help', 'psychology'],
#              'conductor': ['concert',
#               'trombone',
#               'make music',
#               'music theory'],
#              'pianist': ['piano', 'keyboard', 'play', 'music'],
#              'film producer': ['film studio',
#               'pseudonym',
#               'make money',
#               'film'],
#              'canoer': ['distance', 'paddle', 'be a navigator', 'canoeing'],
#              'seiyū': ['school',
#               'variety of names',
#               'be',
#               'Japanese literature'],
#              'amateur wrestler': ['wrestling school',
#               'belt buckle',
#               'win',
#               'psychology'],
#              'chemist': ['laboratory',
#               'microscope',
#               'make things',
#               'chemistry'],
#              'jurist': ['law firm', 'jurisprudence', 'decide', 'law'],
#              'linguist': ['distance',
#               'dictionary',
#               'interpret',
#               'linguistics'],
#              'playwright': ['theatre',
#               'pseudonym',
#               'tell a story',
#               'playwriting'],
#              'association football referee': ['match',
#               'number system',
#               'officiate matches',
#               'refereeing'],
#              'rower': ['racecourse', 'rowing machine', 'row', 'rowing'],
#              'trade unionist': ['factory',
#               'hammer',
#               'fight for you',
#               'economics'],
#              'rugby league player': ['rugby league club',
#               'helmet',
#               'win',
#               'sports science'],
#              'figure skater': ['rink',
#               'skateboard',
#               'entertain',
#               'figure skating'],
#              'record producer': ['record label',
#               'pseudonym',
#               'make music',
#               'music'],
#              'cinematographer': ['film studio',
#               'tripod',
#               'tell a story',
#               'cinematography'],
#              'artistic gymnast': ['competition',
#               'balance beam',
#               'perform',
#               'gymnastics'],
#              'field hockey player': ['field hockey club',
#               'stick',
#               'win',
#               'field hockey'],
#              'astronomer': ['telescope', 'telescope', 'observe', 'astronomy'],
#              'jazz musician': ['jazz club',
#               'trombone',
#               'entertain',
#               'jazz theory'],
#              'comics artist': ['comic shop',
#               'pencil',
#               'tell a story',
#               'art history'],
#              'soldier': ['checkpoint', 'gun', 'kill', 'military science'],
#              'banker': ['bank', 'calculator', 'make money', 'economics'],
#              'opera singer': ['theatre', 'microphone', 'sing', 'opera'],
#              'sportsperson': ['sports club',
#               'wheelchair',
#               'win',
#               'sports science'],
#              'fencer': ['fencing school', 'sabre', 'win', 'fencing'],
#              'illustrator': ['museum', 'pencil', 'illustrate', 'illustration'],
#              'zoologist': ['zoo', 'microscope', 'understand', 'zoology'],
#              'golfer': ['golf course', 'putter', 'win', 'golf'],
#              'art historian': ['museum',
#               'variety of terms',
#               'tell the truth',
#               'art history'],
#              'farmer': ['farm', 'tractor', 'feed his family', 'agriculture'],
#              'voice actor': ['radio station',
#               'variety of voices',
#               'make you laugh',
#               'voice acting'],
#              'music educator': ['music school',
#               'musical instrument',
#               'teach',
#               'music education'],
#              'surgeon': ['hospital', 'scalpel', 'save lives', 'surgery'],
#              'guitarist': ['restaurant', 'guitar', 'play', 'music'],
#              'yachtmaster': ['yachtyard',
#               'sailboat',
#               'master the boat',
#               'yachtbuilding'],
#              'judoka': ['judo school', 'judo belt', 'win', 'judo'],
#              'basketball coach': ['high school',
#               'video game',
#               'win',
#               'education'],
#              'radio personality': ['radio station',
#               'pseudonym',
#               'entertain',
#               'radio broadcasting'],
#              'musicologist': ['university',
#               'musical notation',
#               'interpret',
#               'musicology'],
#              'av idol': ['temple', 'katana', 'protect the idol', 'psychology'],
#              'aviator': ['factory',
#               'parachute',
#               'fly',
#               'aeronautical engineering'],
#              'publisher': ['publisher',
#               'pseudonym',
#               'sell books',
#               'journalism'],
#              'anthropologist': ['university',
#               'microscope',
#               'understand',
#               'anthropology'],
#              'biathlete': ['ski resort',
#               'cross-country ski',
#               'win',
#               'biathlon'],
#              'announcer': ['radio station',
#               'microphone',
#               'tell the truth',
#               'journalism'],
#              'choreographer': ['distance',
#               'variety of techniques',
#               'choreograph',
#               'dance'],
#              'speed skater': ['speed', 'sled', 'be fast', 'speed skating'],
#              'educator': ['school', 'computer', 'teach', 'education'],
#              'sociologist': ['university',
#               'sociological approach',
#               'understand',
#               'sociology'],
#              "children's writer": ['library',
#               'pseudonym',
#               'tell a story',
#               'English literature'],
#              'racecar driver': ['racecar factory',
#               'clutch',
#               'win',
#               'mechanical engineering'],
#              'computer scientist': ['university',
#               'computer',
#               'solve problems',
#               'computer science'],
#              'mangaka': ['restaurant',
#               'katana',
#               'make a mess',
#               'Japanese literature'],
#              'alpine skier': ['ski resort', 'sled', 'ski', 'skiing'],
#              'psychiatrist': ['psychiatric hospital',
#               'computer',
#               'diagnose',
#               'psychiatry'],
#              'literary critic': ['distance',
#               'pseudonym',
#               'tell the truth',
#               'literature'],
#              'missionary': ['church', 'condom', 'love', 'theology'],
#              'mixed martial artist': ['gym',
#               'belt buckle',
#               'win',
#               'psychology'],
#              'geologist': ['mine', 'compass', 'understand', 'geology'],
#              'beauty pageant contestant': ['beauty salon',
#               'mirror',
#               'win',
#               'psychology'],
#              'archaeologist': ['site',
#               'microscope',
#               'find the truth',
#               'archaeology'],
#              'sprinter': ['distance', "sprinter's shoe", 'win', 'athletics'],
#              'head coach': ['university',
#               'number system',
#               'win',
#               'sports administration'],
#              'comedian': ['comedy club', 'joke', 'entertain', 'comedy'],
#              'racing driver': ['racing team',
#               'number plate',
#               'win',
#               'mechanical engineering'],
#              'cleric': ['mosque', 'cross', 'pray', 'theology'],
#              'editor': ['newspaper',
#               'typewriter',
#               'tell the truth',
#               'journalism'],
#              'sport shooter': ['gun range',
#               'rifle',
#               'shoot',
#               'sport shooting'],
#              'minister': ['church', 'gun?', 'lead', 'political science'],
#              'theatre director': ['theatre', 'camera', 'direct', 'theatre'],
#              'non-fiction writer': ['distance',
#               'pseudonym',
#               'tell the truth',
#               'English'],
#              'biologist': ['zoo', 'microscope', 'understand', 'biology'],
#              'police officer': ['police station',
#               'stun gun',
#               'protect and serve',
#               'police science'],
#              'herpetologist': ['zoo', 'microscope', 'find them', 'zoology'],
#              'motorcycle racer': ['motorcycle shop',
#               'helmet',
#               'win',
#               'motorcycling'],
#              'diver': ['dive site',
#               "diver's mask",
#               'save the day',
#               'divership'],
#              'visual artist': ['gallery',
#               'variety of techniques',
#               'tell a story',
#               'art history'],
#              'monk': ['monastery', 'cross', 'teach', 'theology'],
#              'tarento': ['distance',
#               'similar technique',
#               'protect',
#               'mathematics'],
#              'rabbi': ['synagogue', 'computer', 'teach', 'Judaism'],
#              'samurai': ['temple', 'sword', 'kill', 'law'],
#              'table tennis player': ['table tennis court',
#               'table tennis racket',
#               'win',
#               'mathematics']})

# %% [markdown]
# A little playground for sanity checking this process:

# %%
from transformers import BartForConditionalGeneration, BartTokenizer

model = BartForConditionalGeneration.from_pretrained("facebook/bart-large", forced_bos_token_id=0)
tok = BartTokenizer.from_pretrained("facebook/bart-large")
example_english_phrase = "An economist's job is to <mask>"
batch = tok(example_english_phrase, return_tensors="pt")
generated_ids = model.generate(batch["input_ids"])
print(tok.batch_decode(generated_ids, skip_special_tokens=True))
# Out:
# ["An economist's job is to find the"]

# %% [markdown]
# # Generate discourse data

# %%
import names_dataset
nd = names_dataset.NameDataset()
all_us_names = nd.get_top_names(n=100, country_alpha2='US')['US']
generic_us_names = [*all_us_names['M'], *all_us_names['F']]

# %%
import random


samples = []
for entity in raw:
    real_name = entity['inputs'][0]['ent_name']
    real_occupation = entity['train_tgts'][0]['ent_name']
    if real_occupation not in occupations:
        continue
        
    fake_name = random.choice(generic_us_names)
    fake_occupation = random.choice(occupations)

    names = {
        'real': real_name,
        'fake': fake_name,
        'none': 'a person',
    }

    occs = {
        'real': real_occupation,
        'fake': fake_occupation,
    }

    context_templates = {
        'primary': 'who works as a {occupation}',
        'secondary': random.choice([
            'who forgot to bring a {tool} to their job at the {location}',
            'who works at a {location} and whose job is to {role}',
        ]),
        'irrelevant': random.choice([
            'who climbed a hill',
        ]),
    }

    for name_kind, name_text in names.items():
        for occ_kind, occ_text in occs.items():
            for context_kind, context_template in context_templates.items():
                fillers = context_words[occ_text]
                context = context_template\
                    .replace('{occupation}', occ_text)\
                    .replace('{location}', fillers[0])\
                    .replace('{tool}', fillers[1])\
                    .replace('{role}', fillers[2])\
                    .replace('{degree}', fillers[3])

                text = f'This is a story about {name_text} {context}.'
                sample = {
                    'condition': {
                        'name': name_kind,
                        'occupation': occ_kind,
                        'context': context_kind,
                    },
                    'labels': {
                        'name': name_text,
                        'occupation': occ_text,
                    },
                    'text': text,
                }
                samples.append(sample)      
                
out_file = pathlib.Path('/raid/lingo/dez/code/knowledge-fluidity/probing-discourse.json')
with out_file.open('w') as handle:
    json.dump(samples, handle)

# %%
samples[1000:1100]
# Out:
# [{'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Patrick', 'occupation': 'radio personality'},
#   'text': 'This is a story about Patrick who works at a radio station and whose job is to entertain.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Patrick', 'occupation': 'radio personality'},
#   'text': 'This is a story about Patrick who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'screenwriter'},
#   'text': 'This is a story about a person who works as a screenwriter.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'screenwriter'},
#   'text': 'This is a story about a person who works at a film studio and whose job is to tell a story.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'screenwriter'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'radio personality'},
#   'text': 'This is a story about a person who works as a radio personality.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'radio personality'},
#   'text': 'This is a story about a person who works at a radio station and whose job is to entertain.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'radio personality'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'wendell bill', 'occupation': 'cricketer'},
#   'text': 'This is a story about wendell bill who works as a cricketer.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'wendell bill', 'occupation': 'cricketer'},
#   'text': 'This is a story about wendell bill who forgot to bring a bat to their job at the cricket ground.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'wendell bill', 'occupation': 'cricketer'},
#   'text': 'This is a story about wendell bill who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'wendell bill',
#    'occupation': 'association football referee'},
#   'text': 'This is a story about wendell bill who works as a association football referee.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'wendell bill',
#    'occupation': 'association football referee'},
#   'text': 'This is a story about wendell bill who forgot to bring a number system to their job at the match.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'wendell bill',
#    'occupation': 'association football referee'},
#   'text': 'This is a story about wendell bill who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'Matthew', 'occupation': 'cricketer'},
#   'text': 'This is a story about Matthew who works as a cricketer.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'Matthew', 'occupation': 'cricketer'},
#   'text': 'This is a story about Matthew who forgot to bring a bat to their job at the cricket ground.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'Matthew', 'occupation': 'cricketer'},
#   'text': 'This is a story about Matthew who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'Matthew', 'occupation': 'association football referee'},
#   'text': 'This is a story about Matthew who works as a association football referee.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Matthew', 'occupation': 'association football referee'},
#   'text': 'This is a story about Matthew who forgot to bring a number system to their job at the match.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Matthew', 'occupation': 'association football referee'},
#   'text': 'This is a story about Matthew who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'cricketer'},
#   'text': 'This is a story about a person who works as a cricketer.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'cricketer'},
#   'text': 'This is a story about a person who forgot to bring a bat to their job at the cricket ground.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'cricketer'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'association football referee'},
#   'text': 'This is a story about a person who works as a association football referee.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'association football referee'},
#   'text': 'This is a story about a person who forgot to bring a number system to their job at the match.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'association football referee'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'politician'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who works as a politician."},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'politician'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who forgot to bring a pseudonym to their job at the political party."},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'politician'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who climbed a hill."},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'lawyer'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who works as a lawyer."},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'lawyer'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who forgot to bring a lawyer to their job at the law firm."},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': "iwan de marchant et d'ansembourg",
#    'occupation': 'lawyer'},
#   'text': "This is a story about iwan de marchant et d'ansembourg who climbed a hill."},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'Cheryl', 'occupation': 'politician'},
#   'text': 'This is a story about Cheryl who works as a politician.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'Cheryl', 'occupation': 'politician'},
#   'text': 'This is a story about Cheryl who forgot to bring a pseudonym to their job at the political party.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'Cheryl', 'occupation': 'politician'},
#   'text': 'This is a story about Cheryl who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'Cheryl', 'occupation': 'lawyer'},
#   'text': 'This is a story about Cheryl who works as a lawyer.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Cheryl', 'occupation': 'lawyer'},
#   'text': 'This is a story about Cheryl who forgot to bring a lawyer to their job at the law firm.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Cheryl', 'occupation': 'lawyer'},
#   'text': 'This is a story about Cheryl who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'politician'},
#   'text': 'This is a story about a person who works as a politician.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'politician'},
#   'text': 'This is a story about a person who forgot to bring a pseudonym to their job at the political party.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'politician'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'lawyer'},
#   'text': 'This is a story about a person who works as a lawyer.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'lawyer'},
#   'text': 'This is a story about a person who forgot to bring a lawyer to their job at the law firm.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'lawyer'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'athletics competitor'},
#   'text': 'This is a story about grzegorz adam urbanowski who works as a athletics competitor.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'athletics competitor'},
#   'text': 'This is a story about grzegorz adam urbanowski who works at a school and whose job is to win.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'athletics competitor'},
#   'text': 'This is a story about grzegorz adam urbanowski who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'handball player'},
#   'text': 'This is a story about grzegorz adam urbanowski who works as a handball player.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'handball player'},
#   'text': 'This is a story about grzegorz adam urbanowski who works at a gym and whose job is to win.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'grzegorz adam urbanowski',
#    'occupation': 'handball player'},
#   'text': 'This is a story about grzegorz adam urbanowski who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'Alejandro', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about Alejandro who works as a athletics competitor.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'Alejandro', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about Alejandro who works at a school and whose job is to win.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'Alejandro', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about Alejandro who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'Alejandro', 'occupation': 'handball player'},
#   'text': 'This is a story about Alejandro who works as a handball player.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Alejandro', 'occupation': 'handball player'},
#   'text': 'This is a story about Alejandro who works at a gym and whose job is to win.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Alejandro', 'occupation': 'handball player'},
#   'text': 'This is a story about Alejandro who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about a person who works as a athletics competitor.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about a person who works at a school and whose job is to win.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'athletics competitor'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'handball player'},
#   'text': 'This is a story about a person who works as a handball player.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'handball player'},
#   'text': 'This is a story about a person who works at a gym and whose job is to win.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'handball player'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'ben whalley', 'occupation': 'film director'},
#   'text': 'This is a story about ben whalley who works as a film director.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'ben whalley', 'occupation': 'film director'},
#   'text': 'This is a story about ben whalley who forgot to bring a pseudonym to their job at the film studio.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'ben whalley', 'occupation': 'film director'},
#   'text': 'This is a story about ben whalley who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'ben whalley', 'occupation': 'volleyball player'},
#   'text': 'This is a story about ben whalley who works as a volleyball player.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'ben whalley', 'occupation': 'volleyball player'},
#   'text': 'This is a story about ben whalley who forgot to bring a net to their job at the restaurant.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'ben whalley', 'occupation': 'volleyball player'},
#   'text': 'This is a story about ben whalley who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'Pedro', 'occupation': 'film director'},
#   'text': 'This is a story about Pedro who works as a film director.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'Pedro', 'occupation': 'film director'},
#   'text': 'This is a story about Pedro who forgot to bring a pseudonym to their job at the film studio.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'Pedro', 'occupation': 'film director'},
#   'text': 'This is a story about Pedro who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'Pedro', 'occupation': 'volleyball player'},
#   'text': 'This is a story about Pedro who works as a volleyball player.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Pedro', 'occupation': 'volleyball player'},
#   'text': 'This is a story about Pedro who forgot to bring a net to their job at the restaurant.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Pedro', 'occupation': 'volleyball player'},
#   'text': 'This is a story about Pedro who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'film director'},
#   'text': 'This is a story about a person who works as a film director.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'film director'},
#   'text': 'This is a story about a person who forgot to bring a pseudonym to their job at the film studio.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'film director'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'volleyball player'},
#   'text': 'This is a story about a person who works as a volleyball player.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'volleyball player'},
#   'text': 'This is a story about a person who forgot to bring a net to their job at the restaurant.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'volleyball player'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'journalist'},
#   'text': 'This is a story about rolandas paulauskas who works as a journalist.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'journalist'},
#   'text': 'This is a story about rolandas paulauskas who forgot to bring a pseudonym to their job at the newspaper.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'journalist'},
#   'text': 'This is a story about rolandas paulauskas who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'composer'},
#   'text': 'This is a story about rolandas paulauskas who works as a composer.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'composer'},
#   'text': 'This is a story about rolandas paulauskas who forgot to bring a synthesizer to their job at the distance.'},
#  {'condition': {'name': 'real', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'rolandas paulauskas', 'occupation': 'composer'},
#   'text': 'This is a story about rolandas paulauskas who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'Chris', 'occupation': 'journalist'},
#   'text': 'This is a story about Chris who works as a journalist.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'Chris', 'occupation': 'journalist'},
#   'text': 'This is a story about Chris who forgot to bring a pseudonym to their job at the newspaper.'},
#  {'condition': {'name': 'fake', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'Chris', 'occupation': 'journalist'},
#   'text': 'This is a story about Chris who climbed a hill.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'Chris', 'occupation': 'composer'},
#   'text': 'This is a story about Chris who works as a composer.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'Chris', 'occupation': 'composer'},
#   'text': 'This is a story about Chris who forgot to bring a synthesizer to their job at the distance.'},
#  {'condition': {'name': 'fake', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'Chris', 'occupation': 'composer'},
#   'text': 'This is a story about Chris who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'journalist'},
#   'text': 'This is a story about a person who works as a journalist.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'journalist'},
#   'text': 'This is a story about a person who forgot to bring a pseudonym to their job at the newspaper.'},
#  {'condition': {'name': 'none', 'occupation': 'real', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'journalist'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'primary'},
#   'labels': {'name': 'a person', 'occupation': 'composer'},
#   'text': 'This is a story about a person who works as a composer.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'secondary'},
#   'labels': {'name': 'a person', 'occupation': 'composer'},
#   'text': 'This is a story about a person who forgot to bring a synthesizer to their job at the distance.'},
#  {'condition': {'name': 'none', 'occupation': 'fake', 'context': 'irrelevant'},
#   'labels': {'name': 'a person', 'occupation': 'composer'},
#   'text': 'This is a story about a person who climbed a hill.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'primary'},
#   'labels': {'name': 'kuc', 'occupation': 'painter'},
#   'text': 'This is a story about kuc who works as a painter.'},
#  {'condition': {'name': 'real', 'occupation': 'real', 'context': 'secondary'},
#   'labels': {'name': 'kuc', 'occupation': 'painter'},
#   'text': 'This is a story about kuc who works at a studio and whose job is to paint.'}]

# %% [markdown]
# # Generate probing data

# %%
import json
import pathlib
import random

formats = (
    '{prefix}{name} works as a {occupation}.',
    '{prefix}{name}, the {occupation}, went to the store.',
    '{prefix}{name}, the {occupation}, attended my wedding last Wednesday.',
    '{prefix}{name}, the {occupation}, is a close friend of mine',
    '{prefix}{name} is tired from working as a {occupation} all day',
    # '{prefix}{name} is a busy {occupation}',
    '{prefix}{name} dreams of becoming a {occupation}.',
    # '{name}',
)

prefixes = (
    ('', 1),
    ('My cousin ', 3),
    ('My mother ', 3),
    ('My father ', 3),
    ('My friend ', 3),
    ('I met a friend named ', 6),
    ('This is a story about how ', 7),
)

samples = []
for _ in range(500000):
    name = random.choice(generic_us_names)
    occupation = random.choice(occupations)
    prefix, token = random.choice(prefixes)
    fmt = random.choice(formats)
    text = fmt.format(
        prefix=prefix,
        name=name,
        occupation=occupation,
    )
    sample = {'text': text, 'label': occupation, 'token': token}
    samples.append(sample)

out_file = pathlib.Path('/raid/lingo/dez/code/knowledge-fluidity/probing-training-generic-names.json')
with out_file.open('w') as handle:
    json.dump(samples, handle)

# %%
import json
import pathlib

samples = []
for entry in raw:
    text = entry['inputs'][0]['ent_name']
    occupation = entry['train_tgts'][0]['ent_name']
    sample = {'text': text, 'label': occupation}
    samples.append(sample)

out_file = pathlib.Path('/raid/lingo/dez/code/knowledge-fluidity/probing-training-real-names.json')
with out_file.open('w') as handle:
    json.dump(samples, handle)
