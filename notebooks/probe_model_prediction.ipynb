# %%
device = 'cuda'

# %%
import transformers

tokenizer = transformers.AutoTokenizer.from_pretrained('bert-base-uncased')
model = transformers.AutoModelForMaskedLM.from_pretrained('bert-base-uncased').to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Make data

# %%
import json
import pathlib

file = pathlib.Path('probing-training-generic-names.json')
with file.open('r') as handle:
    samples = json.load(handle)
samples
# Out:
# [{'text': 'Carlos, the missionary, attended my wedding last Wednesday.',
#   'label': 'missionary',
#   'token': 1},
#  {'text': 'My mother Christine, the rugby union player, went to the store.',
#   'label': 'rugby union player',
#   'token': 3},
#  {'text': 'My friend Lori is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 3},
#  {'text': 'My father Josh dreams of becoming a television actor.',
#   'label': 'television actor',
#   'token': 3},
#  {'text': 'My mother Sharon, the stage actor, attended my wedding last Wednesday.',
#   'label': 'stage actor',
#   'token': 3},
#  {'text': 'My mother Julia, the diplomat, attended my wedding last Wednesday.',
#   'label': 'diplomat',
#   'token': 3},
#  {'text': 'My friend Paula is tired from working as a entrepreneur all day',
#   'label': 'entrepreneur',
#   'token': 3},
#  {'text': 'My father Christina is tired from working as a sport shooter all day',
#   'label': 'sport shooter',
#   'token': 3},
#  {'text': "My mother Scott works as a children's writer.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'I met a friend named Jaime, the farmer, is a close friend of mine',
#   'label': 'farmer',
#   'token': 6},
#  {'text': 'My father Natalie dreams of becoming a educator.',
#   'label': 'educator',
#   'token': 3},
#  {'text': 'I met a friend named Martin, the missionary, is a close friend of mine',
#   'label': 'missionary',
#   'token': 6},
#  {'text': 'My friend Sergio, the racing driver, went to the store.',
#   'label': 'racing driver',
#   'token': 3},
#  {'text': 'My friend Vanessa, the surgeon, went to the store.',
#   'label': 'surgeon',
#   'token': 3},
#  {'text': 'I met a friend named Cindy dreams of becoming a sport cyclist.',
#   'label': 'sport cyclist',
#   'token': 6},
#  {'text': 'Christine is tired from working as a author all day',
#   'label': 'author',
#   'token': 1},
#  {'text': 'I met a friend named Carol, the architect, is a close friend of mine',
#   'label': 'architect',
#   'token': 6},
#  {'text': 'My cousin Alicia works as a basketball player.',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'My mother Crystal, the yachtmaster, is a close friend of mine',
#   'label': 'yachtmaster',
#   'token': 3},
#  {'text': 'My friend Greg is tired from working as a racing driver all day',
#   'label': 'racing driver',
#   'token': 3},
#  {'text': 'I met a friend named Oscar is tired from working as a golfer all day',
#   'label': 'golfer',
#   'token': 6},
#  {'text': 'Julia, the trade unionist, went to the store.',
#   'label': 'trade unionist',
#   'token': 1},
#  {'text': 'I met a friend named Liz, the handball player, is a close friend of mine',
#   'label': 'handball player',
#   'token': 6},
#  {'text': 'My mother Nick, the fencer, attended my wedding last Wednesday.',
#   'label': 'fencer',
#   'token': 3},
#  {'text': 'My mother Michael, the author, went to the store.',
#   'label': 'author',
#   'token': 3},
#  {'text': 'My father Jonathan, the tennis player, went to the store.',
#   'label': 'tennis player',
#   'token': 3},
#  {'text': 'My mother Susan, the politician, attended my wedding last Wednesday.',
#   'label': 'politician',
#   'token': 3},
#  {'text': 'My cousin Wendy is tired from working as a motorcycle racer all day',
#   'label': 'motorcycle racer',
#   'token': 3},
#  {'text': 'My cousin Leslie, the table tennis player, attended my wedding last Wednesday.',
#   'label': 'table tennis player',
#   'token': 3},
#  {'text': 'My father Justin works as a samurai.',
#   'label': 'samurai',
#   'token': 3},
#  {'text': 'Angel dreams of becoming a rugby union player.',
#   'label': 'rugby union player',
#   'token': 1},
#  {'text': 'This is a story about how Teresa works as a swimmer.',
#   'label': 'swimmer',
#   'token': 7},
#  {'text': 'My cousin Danielle dreams of becoming a mathematician.',
#   'label': 'mathematician',
#   'token': 3},
#  {'text': 'I met a friend named Monica works as a businessperson.',
#   'label': 'businessperson',
#   'token': 6},
#  {'text': 'This is a story about how Andrea, the film actor, went to the store.',
#   'label': 'film actor',
#   'token': 7},
#  {'text': 'I met a friend named Eduardo is tired from working as a priest all day',
#   'label': 'priest',
#   'token': 6},
#  {'text': 'My cousin Mario, the mathematician, attended my wedding last Wednesday.',
#   'label': 'mathematician',
#   'token': 3},
#  {'text': 'My father Stephanie works as a basketball coach.',
#   'label': 'basketball coach',
#   'token': 3},
#  {'text': 'Gary, the herpetologist, went to the store.',
#   'label': 'herpetologist',
#   'token': 1},
#  {'text': 'My friend Juan works as a guitarist.',
#   'label': 'guitarist',
#   'token': 3},
#  {'text': 'My father Michael, the astronomer, is a close friend of mine',
#   'label': 'astronomer',
#   'token': 3},
#  {'text': 'My cousin Kim works as a swimmer.', 'label': 'swimmer', 'token': 3},
#  {'text': 'My friend Vanessa, the singer-songwriter, is a close friend of mine',
#   'label': 'singer-songwriter',
#   'token': 3},
#  {'text': 'My friend Joe dreams of becoming a singer.',
#   'label': 'singer',
#   'token': 3},
#  {'text': 'My friend Ricardo dreams of becoming a television presenter.',
#   'label': 'television presenter',
#   'token': 3},
#  {'text': 'This is a story about how Steve dreams of becoming a art historian.',
#   'label': 'art historian',
#   'token': 7},
#  {'text': 'My father Antonio, the composer, went to the store.',
#   'label': 'composer',
#   'token': 3},
#  {'text': 'I met a friend named Sergio is tired from working as a theatre director all day',
#   'label': 'theatre director',
#   'token': 6},
#  {'text': 'My mother Jim dreams of becoming a association football referee.',
#   'label': 'association football referee',
#   'token': 3},
#  {'text': 'My friend Mario, the handball player, is a close friend of mine',
#   'label': 'handball player',
#   'token': 3},
#  {'text': 'I met a friend named Norma works as a amateur wrestler.',
#   'label': 'amateur wrestler',
#   'token': 6},
#  {'text': 'This is a story about how Paula dreams of becoming a lawyer.',
#   'label': 'lawyer',
#   'token': 7},
#  {'text': 'My cousin Jackie dreams of becoming a psychologist.',
#   'label': 'psychologist',
#   'token': 3},
#  {'text': 'My father Adam dreams of becoming a biathlete.',
#   'label': 'biathlete',
#   'token': 3},
#  {'text': 'I met a friend named Yolanda, the computer scientist, attended my wedding last Wednesday.',
#   'label': 'computer scientist',
#   'token': 6},
#  {'text': 'Debbie, the songwriter, attended my wedding last Wednesday.',
#   'label': 'songwriter',
#   'token': 1},
#  {'text': 'My cousin Wendy is tired from working as a missionary all day',
#   'label': 'missionary',
#   'token': 3},
#  {'text': 'Carlos, the minister, attended my wedding last Wednesday.',
#   'label': 'minister',
#   'token': 1},
#  {'text': 'My mother Josh is tired from working as a priest all day',
#   'label': 'priest',
#   'token': 3},
#  {'text': 'My cousin Paul dreams of becoming a rabbi.',
#   'label': 'rabbi',
#   'token': 3},
#  {'text': 'My cousin Teresa is tired from working as a rugby union player all day',
#   'label': 'rugby union player',
#   'token': 3},
#  {'text': 'Adriana, the radio personality, attended my wedding last Wednesday.',
#   'label': 'radio personality',
#   'token': 1},
#  {'text': 'This is a story about how Claudia works as a tarento.',
#   'label': 'tarento',
#   'token': 7},
#  {'text': 'I met a friend named Cheryl, the diplomat, attended my wedding last Wednesday.',
#   'label': 'diplomat',
#   'token': 6},
#  {'text': 'This is a story about how Frank, the sprinter, is a close friend of mine',
#   'label': 'sprinter',
#   'token': 7},
#  {'text': 'My father Marie is tired from working as a cricketer all day',
#   'label': 'cricketer',
#   'token': 3},
#  {'text': 'I met a friend named Julie, the opera singer, went to the store.',
#   'label': 'opera singer',
#   'token': 6},
#  {'text': 'I met a friend named Teresa is tired from working as a swimmer all day',
#   'label': 'swimmer',
#   'token': 6},
#  {'text': 'My friend Manuel, the cricketer, is a close friend of mine',
#   'label': 'cricketer',
#   'token': 3},
#  {'text': 'My father Norma, the voice actor, is a close friend of mine',
#   'label': 'voice actor',
#   'token': 3},
#  {'text': 'This is a story about how Kim, the volleyball player, went to the store.',
#   'label': 'volleyball player',
#   'token': 7},
#  {'text': 'My father Claudia is tired from working as a teacher all day',
#   'label': 'teacher',
#   'token': 3},
#  {'text': 'I met a friend named Chris, the zoologist, is a close friend of mine',
#   'label': 'zoologist',
#   'token': 6},
#  {'text': 'My cousin Sean is tired from working as a athletics competitor all day',
#   'label': 'athletics competitor',
#   'token': 3},
#  {'text': 'I met a friend named Kyle dreams of becoming a literary critic.',
#   'label': 'literary critic',
#   'token': 6},
#  {'text': 'This is a story about how Erika, the association football referee, went to the store.',
#   'label': 'association football referee',
#   'token': 7},
#  {'text': 'This is a story about how Christine, the minister, attended my wedding last Wednesday.',
#   'label': 'minister',
#   'token': 7},
#  {'text': 'My friend Charles is tired from working as a psychiatrist all day',
#   'label': 'psychiatrist',
#   'token': 3},
#  {'text': 'This is a story about how Patricia is tired from working as a cricketer all day',
#   'label': 'cricketer',
#   'token': 7},
#  {'text': 'My father Vanessa works as a painter.',
#   'label': 'painter',
#   'token': 3},
#  {'text': 'My father Victoria, the ice hockey player, went to the store.',
#   'label': 'ice hockey player',
#   'token': 3},
#  {'text': 'My friend Rebecca, the anthropologist, attended my wedding last Wednesday.',
#   'label': 'anthropologist',
#   'token': 3},
#  {'text': 'My father Brandon, the editor, is a close friend of mine',
#   'label': 'editor',
#   'token': 3},
#  {'text': 'My mother Cesar dreams of becoming a samurai.',
#   'label': 'samurai',
#   'token': 3},
#  {'text': 'This is a story about how Kim, the zoologist, went to the store.',
#   'label': 'zoologist',
#   'token': 7},
#  {'text': 'This is a story about how Teresa, the tarento, went to the store.',
#   'label': 'tarento',
#   'token': 7},
#  {'text': 'I met a friend named Francisco, the illustrator, is a close friend of mine',
#   'label': 'illustrator',
#   'token': 6},
#  {'text': 'Stephen is tired from working as a entomologist all day',
#   'label': 'entomologist',
#   'token': 1},
#  {'text': 'My mother Tyler, the rugby union player, went to the store.',
#   'label': 'rugby union player',
#   'token': 3},
#  {'text': 'My cousin Shannon works as a stage actor.',
#   'label': 'stage actor',
#   'token': 3},
#  {'text': 'Michael is tired from working as a cleric all day',
#   'label': 'cleric',
#   'token': 1},
#  {'text': 'I met a friend named John is tired from working as a theatre director all day',
#   'label': 'theatre director',
#   'token': 6},
#  {'text': 'I met a friend named Jasmine, the actor, went to the store.',
#   'label': 'actor',
#   'token': 6},
#  {'text': 'My mother Josh dreams of becoming a journalist.',
#   'label': 'journalist',
#   'token': 3},
#  {'text': 'Sharon, the film producer, attended my wedding last Wednesday.',
#   'label': 'film producer',
#   'token': 1},
#  {'text': 'I met a friend named Lisa, the rugby union player, is a close friend of mine',
#   'label': 'rugby union player',
#   'token': 6},
#  {'text': 'My father Paul works as a alpine skier.',
#   'label': 'alpine skier',
#   'token': 3},
#  {'text': 'My mother Emma, the teacher, attended my wedding last Wednesday.',
#   'label': 'teacher',
#   'token': 3},
#  {'text': 'My mother Oscar works as a journalist.',
#   'label': 'journalist',
#   'token': 3},
#  {'text': 'My friend Scott, the film director, attended my wedding last Wednesday.',
#   'label': 'film director',
#   'token': 3},
#  {'text': 'I met a friend named Carmen, the farmer, went to the store.',
#   'label': 'farmer',
#   'token': 6},
#  {'text': 'This is a story about how Luis, the head coach, went to the store.',
#   'label': 'head coach',
#   'token': 7},
#  {'text': 'My friend Bryan works as a tarento.',
#   'label': 'tarento',
#   'token': 3},
#  {'text': 'My father Javier works as a journalist.',
#   'label': 'journalist',
#   'token': 3},
#  {'text': 'Gloria dreams of becoming a sociologist.',
#   'label': 'sociologist',
#   'token': 1},
#  {'text': 'I met a friend named Greg, the priest, is a close friend of mine',
#   'label': 'priest',
#   'token': 6},
#  {'text': 'This is a story about how Danielle works as a choreographer.',
#   'label': 'choreographer',
#   'token': 7},
#  {'text': 'I met a friend named Brittany, the opera singer, went to the store.',
#   'label': 'opera singer',
#   'token': 6},
#  {'text': 'This is a story about how Rafael, the photographer, went to the store.',
#   'label': 'photographer',
#   'token': 7},
#  {'text': 'My friend Jack works as a badminton player.',
#   'label': 'badminton player',
#   'token': 3},
#  {'text': 'My mother Jesus works as a chess player.',
#   'label': 'chess player',
#   'token': 3},
#  {'text': 'This is a story about how Kayla, the architect, is a close friend of mine',
#   'label': 'architect',
#   'token': 7},
#  {'text': 'My mother Hector, the philosopher, is a close friend of mine',
#   'label': 'philosopher',
#   'token': 3},
#  {'text': 'My friend Jorge, the cricketer, went to the store.',
#   'label': 'cricketer',
#   'token': 3},
#  {'text': 'Yolanda works as a aviator.', 'label': 'aviator', 'token': 1},
#  {'text': 'I met a friend named Emma dreams of becoming a speed skater.',
#   'label': 'speed skater',
#   'token': 6},
#  {'text': 'I met a friend named James dreams of becoming a farmer.',
#   'label': 'farmer',
#   'token': 6},
#  {'text': 'My mother Rebecca dreams of becoming a politician.',
#   'label': 'politician',
#   'token': 3},
#  {'text': 'My mother Jose is tired from working as a linguist all day',
#   'label': 'linguist',
#   'token': 3},
#  {'text': 'Mike, the playwright, went to the store.',
#   'label': 'playwright',
#   'token': 1},
#  {'text': 'I met a friend named Sara works as a journalist.',
#   'label': 'journalist',
#   'token': 6},
#  {'text': 'My father Eduardo dreams of becoming a cinematographer.',
#   'label': 'cinematographer',
#   'token': 3},
#  {'text': 'My friend Raul, the television actor, attended my wedding last Wednesday.',
#   'label': 'television actor',
#   'token': 3},
#  {'text': 'My father Christina is tired from working as a police officer all day',
#   'label': 'police officer',
#   'token': 3},
#  {'text': 'My mother George, the film actor, is a close friend of mine',
#   'label': 'film actor',
#   'token': 3},
#  {'text': 'My mother Joseph, the playwright, attended my wedding last Wednesday.',
#   'label': 'playwright',
#   'token': 3},
#  {'text': 'My father Jason, the australian rules footballer, is a close friend of mine',
#   'label': 'australian rules footballer',
#   'token': 3},
#  {'text': 'My mother Nancy, the priest, is a close friend of mine',
#   'label': 'priest',
#   'token': 3},
#  {'text': 'My father Brian works as a farmer.', 'label': 'farmer', 'token': 3},
#  {'text': 'Shannon, the stage actor, went to the store.',
#   'label': 'stage actor',
#   'token': 1},
#  {'text': 'My friend Katie works as a singer.', 'label': 'singer', 'token': 3},
#  {'text': 'I met a friend named Nicole, the rugby league player, is a close friend of mine',
#   'label': 'rugby league player',
#   'token': 6},
#  {'text': "My friend Francisco, the children's writer, attended my wedding last Wednesday.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'My cousin Claudia works as a pianist.',
#   'label': 'pianist',
#   'token': 3},
#  {'text': 'My friend Taylor works as a literary critic.',
#   'label': 'literary critic',
#   'token': 3},
#  {'text': 'I met a friend named Daniel works as a alpine skier.',
#   'label': 'alpine skier',
#   'token': 6},
#  {'text': 'Julia dreams of becoming a musicologist.',
#   'label': 'musicologist',
#   'token': 1},
#  {'text': 'My cousin Veronica, the rabbi, went to the store.',
#   'label': 'rabbi',
#   'token': 3},
#  {'text': 'My cousin Joseph, the handball player, is a close friend of mine',
#   'label': 'handball player',
#   'token': 3},
#  {'text': 'This is a story about how Antonio, the screenwriter, went to the store.',
#   'label': 'screenwriter',
#   'token': 7},
#  {'text': 'This is a story about how Rosa, the canoer, is a close friend of mine',
#   'label': 'canoer',
#   'token': 7},
#  {'text': 'I met a friend named Scott, the visual artist, attended my wedding last Wednesday.',
#   'label': 'visual artist',
#   'token': 6},
#  {'text': 'My mother Brittany works as a writer.',
#   'label': 'writer',
#   'token': 3},
#  {'text': 'My father Roberto, the head coach, went to the store.',
#   'label': 'head coach',
#   'token': 3},
#  {'text': 'My cousin Omar, the rower, is a close friend of mine',
#   'label': 'rower',
#   'token': 3},
#  {'text': 'Rafael, the comedian, went to the store.',
#   'label': 'comedian',
#   'token': 1},
#  {'text': 'I met a friend named Charles works as a economist.',
#   'label': 'economist',
#   'token': 6},
#  {'text': 'I met a friend named Matthew, the diplomat, went to the store.',
#   'label': 'diplomat',
#   'token': 6},
#  {'text': 'My father Pedro, the novelist, is a close friend of mine',
#   'label': 'novelist',
#   'token': 3},
#  {'text': 'This is a story about how Jason, the guitarist, went to the store.',
#   'label': 'guitarist',
#   'token': 7},
#  {'text': 'My cousin Victoria, the film director, is a close friend of mine',
#   'label': 'film director',
#   'token': 3},
#  {'text': 'This is a story about how Cynthia works as a speed skater.',
#   'label': 'speed skater',
#   'token': 7},
#  {'text': 'Steven, the musician, attended my wedding last Wednesday.',
#   'label': 'musician',
#   'token': 1},
#  {'text': 'I met a friend named Juan, the model, attended my wedding last Wednesday.',
#   'label': 'model',
#   'token': 6},
#  {'text': 'My mother Jonathan dreams of becoming a record producer.',
#   'label': 'record producer',
#   'token': 3},
#  {'text': 'My cousin Joel, the biathlete, attended my wedding last Wednesday.',
#   'label': 'biathlete',
#   'token': 3},
#  {'text': 'My friend Rebecca, the singer, went to the store.',
#   'label': 'singer',
#   'token': 3},
#  {'text': 'My mother Cesar dreams of becoming a painter.',
#   'label': 'painter',
#   'token': 3},
#  {'text': 'I met a friend named Sara, the visual artist, went to the store.',
#   'label': 'visual artist',
#   'token': 6},
#  {'text': 'This is a story about how Pamela works as a fencer.',
#   'label': 'fencer',
#   'token': 7},
#  {'text': 'My father Norma, the catholic priest, is a close friend of mine',
#   'label': 'catholic priest',
#   'token': 3},
#  {'text': 'My mother Debbie dreams of becoming a singer.',
#   'label': 'singer',
#   'token': 3},
#  {'text': 'Charles dreams of becoming a writer.',
#   'label': 'writer',
#   'token': 1},
#  {'text': 'My cousin Mary, the field hockey player, is a close friend of mine',
#   'label': 'field hockey player',
#   'token': 3},
#  {'text': 'My father Monica dreams of becoming a conductor.',
#   'label': 'conductor',
#   'token': 3},
#  {'text': 'My cousin Yolanda dreams of becoming a cleric.',
#   'label': 'cleric',
#   'token': 3},
#  {'text': 'My mother Martha, the artistic gymnast, attended my wedding last Wednesday.',
#   'label': 'artistic gymnast',
#   'token': 3},
#  {'text': 'My friend Frank, the cinematographer, is a close friend of mine',
#   'label': 'cinematographer',
#   'token': 3},
#  {'text': 'Cesar works as a music educator.',
#   'label': 'music educator',
#   'token': 1},
#  {'text': 'My friend Paula, the actor, went to the store.',
#   'label': 'actor',
#   'token': 3},
#  {'text': 'My father Stephanie works as a judoka.',
#   'label': 'judoka',
#   'token': 3},
#  {'text': 'My mother Megan is tired from working as a baseball player all day',
#   'label': 'baseball player',
#   'token': 3},
#  {'text': 'My friend Adrian, the cinematographer, attended my wedding last Wednesday.',
#   'label': 'cinematographer',
#   'token': 3},
#  {'text': 'Amanda, the theologian, is a close friend of mine',
#   'label': 'theologian',
#   'token': 1},
#  {'text': 'This is a story about how Oscar works as a yachtmaster.',
#   'label': 'yachtmaster',
#   'token': 7},
#  {'text': 'Kyle, the conductor, attended my wedding last Wednesday.',
#   'label': 'conductor',
#   'token': 1},
#  {'text': 'My friend Mike works as a minister.',
#   'label': 'minister',
#   'token': 3},
#  {'text': 'My mother Sara, the literary critic, is a close friend of mine',
#   'label': 'literary critic',
#   'token': 3},
#  {'text': 'Janet dreams of becoming a figure skater.',
#   'label': 'figure skater',
#   'token': 1},
#  {'text': 'My cousin Justin, the actor, went to the store.',
#   'label': 'actor',
#   'token': 3},
#  {'text': 'My mother Kayla is tired from working as a cinematographer all day',
#   'label': 'cinematographer',
#   'token': 3},
#  {'text': 'I met a friend named Alicia, the tarento, attended my wedding last Wednesday.',
#   'label': 'tarento',
#   'token': 6},
#  {'text': 'My cousin Kyle is tired from working as a opera singer all day',
#   'label': 'opera singer',
#   'token': 3},
#  {'text': 'My father Pamela dreams of becoming a priest.',
#   'label': 'priest',
#   'token': 3},
#  {'text': 'My mother Jack, the missionary, is a close friend of mine',
#   'label': 'missionary',
#   'token': 3},
#  {'text': 'My friend Megan is tired from working as a mathematician all day',
#   'label': 'mathematician',
#   'token': 3},
#  {'text': 'This is a story about how Jonathan, the poet, is a close friend of mine',
#   'label': 'poet',
#   'token': 7},
#  {'text': 'My cousin Danny works as a baseball player.',
#   'label': 'baseball player',
#   'token': 3},
#  {'text': 'This is a story about how Sandy is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 7},
#  {'text': 'My mother William is tired from working as a association football referee all day',
#   'label': 'association football referee',
#   'token': 3},
#  {'text': 'I met a friend named Danny dreams of becoming a record producer.',
#   'label': 'record producer',
#   'token': 6},
#  {'text': 'This is a story about how Anna, the sportsperson, went to the store.',
#   'label': 'sportsperson',
#   'token': 7},
#  {'text': 'My father Nancy, the poet, went to the store.',
#   'label': 'poet',
#   'token': 3},
#  {'text': 'Kimberly, the racecar driver, went to the store.',
#   'label': 'racecar driver',
#   'token': 1},
#  {'text': 'My cousin Linda works as a television actor.',
#   'label': 'television actor',
#   'token': 3},
#  {'text': 'I met a friend named Hector works as a australian rules footballer.',
#   'label': 'australian rules footballer',
#   'token': 6},
#  {'text': 'This is a story about how Rosa is tired from working as a golfer all day',
#   'label': 'golfer',
#   'token': 7},
#  {'text': 'My mother Debbie, the comedian, is a close friend of mine',
#   'label': 'comedian',
#   'token': 3},
#  {'text': 'Liz, the screenwriter, is a close friend of mine',
#   'label': 'screenwriter',
#   'token': 1},
#  {'text': 'My friend Rebecca dreams of becoming a sportsperson.',
#   'label': 'sportsperson',
#   'token': 3},
#  {'text': 'My friend Sharon, the ice hockey player, attended my wedding last Wednesday.',
#   'label': 'ice hockey player',
#   'token': 3},
#  {'text': 'This is a story about how Christopher is tired from working as a sportsperson all day',
#   'label': 'sportsperson',
#   'token': 7},
#  {'text': 'I met a friend named Rosa works as a judoka.',
#   'label': 'judoka',
#   'token': 6},
#  {'text': 'My friend Thomas, the archaeologist, went to the store.',
#   'label': 'archaeologist',
#   'token': 3},
#  {'text': 'This is a story about how Debbie, the record producer, went to the store.',
#   'label': 'record producer',
#   'token': 7},
#  {'text': 'My mother Christine, the monk, attended my wedding last Wednesday.',
#   'label': 'monk',
#   'token': 3},
#  {'text': "My friend Janet dreams of becoming a children's writer.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'My cousin Mary, the translator, is a close friend of mine',
#   'label': 'translator',
#   'token': 3},
#  {'text': 'My cousin Tony works as a racecar driver.',
#   'label': 'racecar driver',
#   'token': 3},
#  {'text': 'My friend Hannah is tired from working as a boxer all day',
#   'label': 'boxer',
#   'token': 3},
#  {'text': 'Paul dreams of becoming a volleyball player.',
#   'label': 'volleyball player',
#   'token': 1},
#  {'text': 'My father Denise dreams of becoming a sport shooter.',
#   'label': 'sport shooter',
#   'token': 3},
#  {'text': 'My friend Josh, the songwriter, went to the store.',
#   'label': 'songwriter',
#   'token': 3},
#  {'text': 'Tyler is tired from working as a theatre director all day',
#   'label': 'theatre director',
#   'token': 1},
#  {'text': 'This is a story about how Roberto, the playwright, went to the store.',
#   'label': 'playwright',
#   'token': 7},
#  {'text': 'My cousin Bryan works as a geologist.',
#   'label': 'geologist',
#   'token': 3},
#  {'text': 'I met a friend named Sam dreams of becoming a film director.',
#   'label': 'film director',
#   'token': 6},
#  {'text': 'My cousin Ashley is tired from working as a entrepreneur all day',
#   'label': 'entrepreneur',
#   'token': 3},
#  {'text': 'My father Sharon, the cleric, attended my wedding last Wednesday.',
#   'label': 'cleric',
#   'token': 3},
#  {'text': 'My mother Greg, the journalist, went to the store.',
#   'label': 'journalist',
#   'token': 3},
#  {'text': 'My cousin Cheryl, the psychologist, is a close friend of mine',
#   'label': 'psychologist',
#   'token': 3},
#  {'text': 'I met a friend named Josh, the samurai, is a close friend of mine',
#   'label': 'samurai',
#   'token': 6},
#  {'text': 'I met a friend named Martha is tired from working as a canoer all day',
#   'label': 'canoer',
#   'token': 6},
#  {'text': 'I met a friend named Cindy, the surgeon, attended my wedding last Wednesday.',
#   'label': 'surgeon',
#   'token': 6},
#  {'text': 'My cousin Gary, the choreographer, went to the store.',
#   'label': 'choreographer',
#   'token': 3},
#  {'text': 'My cousin Cynthia, the cleric, is a close friend of mine',
#   'label': 'cleric',
#   'token': 3},
#  {'text': 'My cousin Alicia, the amateur wrestler, went to the store.',
#   'label': 'amateur wrestler',
#   'token': 3},
#  {'text': 'I met a friend named Alejandro works as a editor.',
#   'label': 'editor',
#   'token': 6},
#  {'text': 'My friend Ryan dreams of becoming a film actor.',
#   'label': 'film actor',
#   'token': 3},
#  {'text': 'My mother Jim, the sculptor, attended my wedding last Wednesday.',
#   'label': 'sculptor',
#   'token': 3},
#  {'text': 'My mother Megan dreams of becoming a sculptor.',
#   'label': 'sculptor',
#   'token': 3},
#  {'text': 'My father Gabriel dreams of becoming a author.',
#   'label': 'author',
#   'token': 3},
#  {'text': 'My father Jenny dreams of becoming a songwriter.',
#   'label': 'songwriter',
#   'token': 3},
#  {'text': 'My friend Javier is tired from working as a lawyer all day',
#   'label': 'lawyer',
#   'token': 3},
#  {'text': 'Jonathan, the linguist, went to the store.',
#   'label': 'linguist',
#   'token': 1},
#  {'text': 'My father Kyle, the entomologist, went to the store.',
#   'label': 'entomologist',
#   'token': 3},
#  {'text': 'I met a friend named Sarah, the volleyball player, is a close friend of mine',
#   'label': 'volleyball player',
#   'token': 6},
#  {'text': 'My father Martin, the lawyer, is a close friend of mine',
#   'label': 'lawyer',
#   'token': 3},
#  {'text': 'This is a story about how Silvia is tired from working as a jurist all day',
#   'label': 'jurist',
#   'token': 7},
#  {'text': 'My father Jaime is tired from working as a stage actor all day',
#   'label': 'stage actor',
#   'token': 3},
#  {'text': 'My father Tom is tired from working as a basketball player all day',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'My father Marie is tired from working as a athletics competitor all day',
#   'label': 'athletics competitor',
#   'token': 3},
#  {'text': 'I met a friend named Veronica is tired from working as a cinematographer all day',
#   'label': 'cinematographer',
#   'token': 6},
#  {'text': 'I met a friend named Gary, the conductor, is a close friend of mine',
#   'label': 'conductor',
#   'token': 6},
#  {'text': 'My father Jose, the educator, went to the store.',
#   'label': 'educator',
#   'token': 3},
#  {'text': 'My mother Norma, the seiyū, went to the store.',
#   'label': 'seiyū',
#   'token': 3},
#  {'text': 'My father Cynthia is tired from working as a sportsperson all day',
#   'label': 'sportsperson',
#   'token': 3},
#  {'text': 'Erica, the comics artist, is a close friend of mine',
#   'label': 'comics artist',
#   'token': 1},
#  {'text': 'This is a story about how Dan, the american football player, went to the store.',
#   'label': 'american football player',
#   'token': 7},
#  {'text': 'I met a friend named Erin, the diplomat, went to the store.',
#   'label': 'diplomat',
#   'token': 6},
#  {'text': 'My friend Marie, the politician, is a close friend of mine',
#   'label': 'politician',
#   'token': 3},
#  {'text': 'My mother Jennifer works as a basketball player.',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'My father Jason, the voice actor, went to the store.',
#   'label': 'voice actor',
#   'token': 3},
#  {'text': 'My father Jason, the samurai, went to the store.',
#   'label': 'samurai',
#   'token': 3},
#  {'text': 'My cousin Antonio dreams of becoming a association football manager.',
#   'label': 'association football manager',
#   'token': 3},
#  {'text': 'This is a story about how Eduardo dreams of becoming a archaeologist.',
#   'label': 'archaeologist',
#   'token': 7},
#  {'text': 'My father Christine works as a architect.',
#   'label': 'architect',
#   'token': 3},
#  {'text': 'My cousin Tim works as a av idol.', 'label': 'av idol', 'token': 3},
#  {'text': 'This is a story about how Raul dreams of becoming a conductor.',
#   'label': 'conductor',
#   'token': 7},
#  {'text': 'My cousin Julie, the astronomer, went to the store.',
#   'label': 'astronomer',
#   'token': 3},
#  {'text': 'This is a story about how Danielle works as a record producer.',
#   'label': 'record producer',
#   'token': 7},
#  {'text': 'My friend Kyle, the surgeon, is a close friend of mine',
#   'label': 'surgeon',
#   'token': 3},
#  {'text': 'This is a story about how Sandy, the seiyū, attended my wedding last Wednesday.',
#   'label': 'seiyū',
#   'token': 7},
#  {'text': 'I met a friend named Kim works as a yachtmaster.',
#   'label': 'yachtmaster',
#   'token': 6},
#  {'text': 'Frank, the art historian, attended my wedding last Wednesday.',
#   'label': 'art historian',
#   'token': 1},
#  {'text': 'This is a story about how Hannah dreams of becoming a diver.',
#   'label': 'diver',
#   'token': 7},
#  {'text': 'Cheryl, the sculptor, attended my wedding last Wednesday.',
#   'label': 'sculptor',
#   'token': 1},
#  {'text': 'My father Jorge, the zoologist, went to the store.',
#   'label': 'zoologist',
#   'token': 3},
#  {'text': 'Kyle is tired from working as a music educator all day',
#   'label': 'music educator',
#   'token': 1},
#  {'text': 'My mother Oscar, the judge, attended my wedding last Wednesday.',
#   'label': 'judge',
#   'token': 3},
#  {'text': 'Nick, the sculptor, attended my wedding last Wednesday.',
#   'label': 'sculptor',
#   'token': 1},
#  {'text': 'Tony, the boxer, went to the store.', 'label': 'boxer', 'token': 1},
#  {'text': 'My friend Rebecca works as a chess player.',
#   'label': 'chess player',
#   'token': 3},
#  {'text': 'My mother Rosa is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 3},
#  {'text': 'I met a friend named Shannon, the screenwriter, is a close friend of mine',
#   'label': 'screenwriter',
#   'token': 6},
#  {'text': 'My mother Pamela works as a amateur wrestler.',
#   'label': 'amateur wrestler',
#   'token': 3},
#  {'text': 'My father Melissa is tired from working as a rower all day',
#   'label': 'rower',
#   'token': 3},
#  {'text': 'My mother Pamela is tired from working as a music educator all day',
#   'label': 'music educator',
#   'token': 3},
#  {'text': 'I met a friend named Linda works as a association football player.',
#   'label': 'association football player',
#   'token': 6},
#  {'text': 'This is a story about how Jordan, the educator, went to the store.',
#   'label': 'educator',
#   'token': 7},
#  {'text': 'I met a friend named Jorge, the pianist, is a close friend of mine',
#   'label': 'pianist',
#   'token': 6},
#  {'text': 'My friend Amy, the politician, attended my wedding last Wednesday.',
#   'label': 'politician',
#   'token': 3},
#  {'text': 'This is a story about how Mary, the ice hockey player, went to the store.',
#   'label': 'ice hockey player',
#   'token': 7},
#  {'text': 'I met a friend named Martha, the motorcycle racer, is a close friend of mine',
#   'label': 'motorcycle racer',
#   'token': 6},
#  {'text': 'My friend Leslie, the speed skater, attended my wedding last Wednesday.',
#   'label': 'speed skater',
#   'token': 3},
#  {'text': 'My cousin Emily is tired from working as a basketball coach all day',
#   'label': 'basketball coach',
#   'token': 3},
#  {'text': 'My cousin Scott, the businessperson, went to the store.',
#   'label': 'businessperson',
#   'token': 3},
#  {'text': 'This is a story about how Diana, the sociologist, attended my wedding last Wednesday.',
#   'label': 'sociologist',
#   'token': 7},
#  {'text': 'My cousin Jasmine dreams of becoming a handball player.',
#   'label': 'handball player',
#   'token': 3},
#  {'text': 'My mother Adam, the botanist, went to the store.',
#   'label': 'botanist',
#   'token': 3},
#  {'text': 'My friend Erica, the beauty pageant contestant, went to the store.',
#   'label': 'beauty pageant contestant',
#   'token': 3},
#  {'text': 'My mother Heather works as a sport shooter.',
#   'label': 'sport shooter',
#   'token': 3},
#  {'text': 'This is a story about how Rafael dreams of becoming a cricketer.',
#   'label': 'cricketer',
#   'token': 7},
#  {'text': 'My cousin Jordan works as a american football player.',
#   'label': 'american football player',
#   'token': 3},
#  {'text': 'My cousin Justin is tired from working as a photographer all day',
#   'label': 'photographer',
#   'token': 3},
#  {'text': 'Martin, the physician, attended my wedding last Wednesday.',
#   'label': 'physician',
#   'token': 1},
#  {'text': 'My father Christina is tired from working as a seiyū all day',
#   'label': 'seiyū',
#   'token': 3},
#  {'text': 'This is a story about how Greg dreams of becoming a publisher.',
#   'label': 'publisher',
#   'token': 7},
#  {'text': 'My cousin Cindy, the aviator, is a close friend of mine',
#   'label': 'aviator',
#   'token': 3},
#  {'text': 'This is a story about how Jesus works as a sculptor.',
#   'label': 'sculptor',
#   'token': 7},
#  {'text': 'My father Mario, the table tennis player, is a close friend of mine',
#   'label': 'table tennis player',
#   'token': 3},
#  {'text': 'This is a story about how Erin, the theologian, attended my wedding last Wednesday.',
#   'label': 'theologian',
#   'token': 7},
#  {'text': 'This is a story about how Kimberly works as a editor.',
#   'label': 'editor',
#   'token': 7},
#  {'text': 'My cousin Michelle dreams of becoming a pianist.',
#   'label': 'pianist',
#   'token': 3},
#  {'text': 'This is a story about how Taylor, the screenwriter, attended my wedding last Wednesday.',
#   'label': 'screenwriter',
#   'token': 7},
#  {'text': 'My friend Jasmine, the basketball player, attended my wedding last Wednesday.',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'My friend Sam works as a philosopher.',
#   'label': 'philosopher',
#   'token': 3},
#  {'text': 'My cousin Rachel, the handball player, went to the store.',
#   'label': 'handball player',
#   'token': 3},
#  {'text': 'My father Leslie works as a baseball player.',
#   'label': 'baseball player',
#   'token': 3},
#  {'text': 'My father Steven is tired from working as a av idol all day',
#   'label': 'av idol',
#   'token': 3},
#  {'text': 'I met a friend named Sarah, the artistic gymnast, went to the store.',
#   'label': 'artistic gymnast',
#   'token': 6},
#  {'text': 'My mother Ricardo, the publisher, is a close friend of mine',
#   'label': 'publisher',
#   'token': 3},
#  {'text': 'I met a friend named Brandon is tired from working as a businessperson all day',
#   'label': 'businessperson',
#   'token': 6},
#  {'text': 'My cousin George works as a rugby union player.',
#   'label': 'rugby union player',
#   'token': 3},
#  {'text': 'My friend Rachel works as a record producer.',
#   'label': 'record producer',
#   'token': 3},
#  {'text': 'Patricia dreams of becoming a computer scientist.',
#   'label': 'computer scientist',
#   'token': 1},
#  {'text': 'Steve works as a painter.', 'label': 'painter', 'token': 1},
#  {'text': 'This is a story about how Jose dreams of becoming a politician.',
#   'label': 'politician',
#   'token': 7},
#  {'text': "My cousin Julia works as a children's writer.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'My cousin Charles, the singer-songwriter, attended my wedding last Wednesday.',
#   'label': 'singer-songwriter',
#   'token': 3},
#  {'text': 'My friend Adriana dreams of becoming a association football referee.',
#   'label': 'association football referee',
#   'token': 3},
#  {'text': 'My mother Matt dreams of becoming a mixed martial artist.',
#   'label': 'mixed martial artist',
#   'token': 3},
#  {'text': 'My cousin Paul, the basketball player, went to the store.',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'My mother Michael, the athletics competitor, attended my wedding last Wednesday.',
#   'label': 'athletics competitor',
#   'token': 3},
#  {'text': 'My father Veronica, the canoer, went to the store.',
#   'label': 'canoer',
#   'token': 3},
#  {'text': 'My mother Jason is tired from working as a sport shooter all day',
#   'label': 'sport shooter',
#   'token': 3},
#  {'text': 'Amber dreams of becoming a rabbi.', 'label': 'rabbi', 'token': 1},
#  {'text': 'My father Mark, the singer, attended my wedding last Wednesday.',
#   'label': 'singer',
#   'token': 3},
#  {'text': 'Jessica is tired from working as a missionary all day',
#   'label': 'missionary',
#   'token': 1},
#  {'text': 'My friend Carol works as a fencer.', 'label': 'fencer', 'token': 3},
#  {'text': 'My father Linda is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 3},
#  {'text': 'My father Crystal, the film director, went to the store.',
#   'label': 'film director',
#   'token': 3},
#  {'text': 'My cousin Christina, the educator, is a close friend of mine',
#   'label': 'educator',
#   'token': 3},
#  {'text': 'My mother Erin is tired from working as a botanist all day',
#   'label': 'botanist',
#   'token': 3},
#  {'text': 'My father Justin is tired from working as a theatre director all day',
#   'label': 'theatre director',
#   'token': 3},
#  {'text': 'My father Yolanda works as a soldier.',
#   'label': 'soldier',
#   'token': 3},
#  {'text': 'Charles is tired from working as a cricketer all day',
#   'label': 'cricketer',
#   'token': 1},
#  {'text': 'Roberto, the association football player, attended my wedding last Wednesday.',
#   'label': 'association football player',
#   'token': 1},
#  {'text': 'I met a friend named Hannah is tired from working as a alpine skier all day',
#   'label': 'alpine skier',
#   'token': 6},
#  {'text': 'My cousin Pedro, the boxer, attended my wedding last Wednesday.',
#   'label': 'boxer',
#   'token': 3},
#  {'text': 'My father Michelle, the guitarist, went to the store.',
#   'label': 'guitarist',
#   'token': 3},
#  {'text': 'My cousin Aaron dreams of becoming a choreographer.',
#   'label': 'choreographer',
#   'token': 3},
#  {'text': 'This is a story about how Jordan is tired from working as a sociologist all day',
#   'label': 'sociologist',
#   'token': 7},
#  {'text': 'Manuel, the mangaka, is a close friend of mine',
#   'label': 'mangaka',
#   'token': 1},
#  {'text': 'My mother Justin is tired from working as a jurist all day',
#   'label': 'jurist',
#   'token': 3},
#  {'text': 'Norma, the non-fiction writer, is a close friend of mine',
#   'label': 'non-fiction writer',
#   'token': 1},
#  {'text': 'This is a story about how Julio, the athletics competitor, went to the store.',
#   'label': 'athletics competitor',
#   'token': 7},
#  {'text': 'My father Amber dreams of becoming a businessperson.',
#   'label': 'businessperson',
#   'token': 3},
#  {'text': 'I met a friend named Mary works as a rower.',
#   'label': 'rower',
#   'token': 6},
#  {'text': 'I met a friend named Cesar is tired from working as a rugby union player all day',
#   'label': 'rugby union player',
#   'token': 6},
#  {'text': 'Paul, the artist, is a close friend of mine',
#   'label': 'artist',
#   'token': 1},
#  {'text': 'Shannon is tired from working as a association football referee all day',
#   'label': 'association football referee',
#   'token': 1},
#  {'text': 'This is a story about how Sean is tired from working as a farmer all day',
#   'label': 'farmer',
#   'token': 7},
#  {'text': 'I met a friend named Dan is tired from working as a military personnel all day',
#   'label': 'military personnel',
#   'token': 6},
#  {'text': 'My friend Maria, the physician, went to the store.',
#   'label': 'physician',
#   'token': 3},
#  {'text': 'Nicole, the baseball player, attended my wedding last Wednesday.',
#   'label': 'baseball player',
#   'token': 1},
#  {'text': 'My friend Brenda works as a novelist.',
#   'label': 'novelist',
#   'token': 3},
#  {'text': 'My friend Sam dreams of becoming a chess player.',
#   'label': 'chess player',
#   'token': 3},
#  {'text': 'I met a friend named Martha is tired from working as a minister all day',
#   'label': 'minister',
#   'token': 6},
#  {'text': 'This is a story about how Erin works as a literary critic.',
#   'label': 'literary critic',
#   'token': 7},
#  {'text': 'I met a friend named Veronica, the entomologist, attended my wedding last Wednesday.',
#   'label': 'entomologist',
#   'token': 6},
#  {'text': 'My father Frank, the songwriter, went to the store.',
#   'label': 'songwriter',
#   'token': 3},
#  {'text': 'This is a story about how Scott is tired from working as a cinematographer all day',
#   'label': 'cinematographer',
#   'token': 7},
#  {'text': 'This is a story about how Hector, the visual artist, attended my wedding last Wednesday.',
#   'label': 'visual artist',
#   'token': 7},
#  {'text': 'My friend Joel dreams of becoming a samurai.',
#   'label': 'samurai',
#   'token': 3},
#  {'text': 'My mother Sam, the farmer, is a close friend of mine',
#   'label': 'farmer',
#   'token': 3},
#  {'text': 'My mother Carol, the conductor, went to the store.',
#   'label': 'conductor',
#   'token': 3},
#  {'text': 'This is a story about how Kyle works as a seiyū.',
#   'label': 'seiyū',
#   'token': 7},
#  {'text': 'My friend Sean works as a priest.', 'label': 'priest', 'token': 3},
#  {'text': 'My mother Kyle is tired from working as a author all day',
#   'label': 'author',
#   'token': 3},
#  {'text': 'My cousin John is tired from working as a soldier all day',
#   'label': 'soldier',
#   'token': 3},
#  {'text': 'This is a story about how Frank is tired from working as a theatre director all day',
#   'label': 'theatre director',
#   'token': 7},
#  {'text': 'My mother Jordan dreams of becoming a cleric.',
#   'label': 'cleric',
#   'token': 3},
#  {'text': 'My mother Brittany, the guitarist, is a close friend of mine',
#   'label': 'guitarist',
#   'token': 3},
#  {'text': 'This is a story about how Steven, the politician, went to the store.',
#   'label': 'politician',
#   'token': 7},
#  {'text': 'My father Victoria is tired from working as a herpetologist all day',
#   'label': 'herpetologist',
#   'token': 3},
#  {'text': 'I met a friend named Joshua is tired from working as a teacher all day',
#   'label': 'teacher',
#   'token': 6},
#  {'text': 'My father Kevin dreams of becoming a translator.',
#   'label': 'translator',
#   'token': 3},
#  {'text': 'My father Joel, the playwright, attended my wedding last Wednesday.',
#   'label': 'playwright',
#   'token': 3},
#  {'text': 'I met a friend named Kathy is tired from working as a amateur wrestler all day',
#   'label': 'amateur wrestler',
#   'token': 6},
#  {'text': 'This is a story about how Tina works as a baseball player.',
#   'label': 'baseball player',
#   'token': 7},
#  {'text': 'My friend Jaime, the cricketer, went to the store.',
#   'label': 'cricketer',
#   'token': 3},
#  {'text': 'This is a story about how Anthony works as a military personnel.',
#   'label': 'military personnel',
#   'token': 7},
#  {'text': 'This is a story about how Jorge works as a psychologist.',
#   'label': 'psychologist',
#   'token': 7},
#  {'text': 'I met a friend named Eric, the geologist, is a close friend of mine',
#   'label': 'geologist',
#   'token': 6},
#  {'text': 'My cousin Cindy, the non-fiction writer, attended my wedding last Wednesday.',
#   'label': 'non-fiction writer',
#   'token': 3},
#  {'text': 'I met a friend named Michelle, the banker, attended my wedding last Wednesday.',
#   'label': 'banker',
#   'token': 6},
#  {'text': 'Denise is tired from working as a missionary all day',
#   'label': 'missionary',
#   'token': 1},
#  {'text': 'I met a friend named Kyle, the banker, went to the store.',
#   'label': 'banker',
#   'token': 6},
#  {'text': 'My father Carmen, the architect, is a close friend of mine',
#   'label': 'architect',
#   'token': 3},
#  {'text': 'My mother Adriana, the composer, went to the store.',
#   'label': 'composer',
#   'token': 3},
#  {'text': 'I met a friend named Jenny, the catholic priest, is a close friend of mine',
#   'label': 'catholic priest',
#   'token': 6},
#  {'text': 'Katie dreams of becoming a cinematographer.',
#   'label': 'cinematographer',
#   'token': 1},
#  {'text': 'My father Thomas, the psychologist, went to the store.',
#   'label': 'psychologist',
#   'token': 3},
#  {'text': 'My friend Lauren, the artistic gymnast, is a close friend of mine',
#   'label': 'artistic gymnast',
#   'token': 3},
#  {'text': 'My mother Brandon works as a basketball player.',
#   'label': 'basketball player',
#   'token': 3},
#  {'text': 'I met a friend named Taylor works as a artist.',
#   'label': 'artist',
#   'token': 6},
#  {'text': 'My father Bob, the publisher, is a close friend of mine',
#   'label': 'publisher',
#   'token': 3},
#  {'text': 'I met a friend named John, the stage actor, is a close friend of mine',
#   'label': 'stage actor',
#   'token': 6},
#  {'text': 'I met a friend named Lauren, the biathlete, attended my wedding last Wednesday.',
#   'label': 'biathlete',
#   'token': 6},
#  {'text': 'My cousin Christian, the motorcycle racer, is a close friend of mine',
#   'label': 'motorcycle racer',
#   'token': 3},
#  {'text': 'Sonia dreams of becoming a model.', 'label': 'model', 'token': 1},
#  {'text': 'My father Lauren, the sculptor, attended my wedding last Wednesday.',
#   'label': 'sculptor',
#   'token': 3},
#  {'text': 'My father Andrew works as a astronomer.',
#   'label': 'astronomer',
#   'token': 3},
#  {'text': 'My cousin Maria, the archaeologist, attended my wedding last Wednesday.',
#   'label': 'archaeologist',
#   'token': 3},
#  {'text': 'My father Jacob is tired from working as a beauty pageant contestant all day',
#   'label': 'beauty pageant contestant',
#   'token': 3},
#  {'text': 'My mother Yolanda, the astronomer, is a close friend of mine',
#   'label': 'astronomer',
#   'token': 3},
#  {'text': 'My father Sara is tired from working as a minister all day',
#   'label': 'minister',
#   'token': 3},
#  {'text': 'My father Sandy, the racing driver, is a close friend of mine',
#   'label': 'racing driver',
#   'token': 3},
#  {'text': 'My friend Ricardo works as a swimmer.',
#   'label': 'swimmer',
#   'token': 3},
#  {'text': 'Martin, the mathematician, is a close friend of mine',
#   'label': 'mathematician',
#   'token': 1},
#  {'text': 'I met a friend named Sara works as a university teacher.',
#   'label': 'university teacher',
#   'token': 6},
#  {'text': 'My friend Greg works as a basketball coach.',
#   'label': 'basketball coach',
#   'token': 3},
#  {'text': 'I met a friend named Brandon, the volleyball player, is a close friend of mine',
#   'label': 'volleyball player',
#   'token': 6},
#  {'text': 'I met a friend named Marie, the politician, is a close friend of mine',
#   'label': 'politician',
#   'token': 6},
#  {'text': 'I met a friend named Silvia, the teacher, went to the store.',
#   'label': 'teacher',
#   'token': 6},
#  {'text': 'My father Erika works as a voice actor.',
#   'label': 'voice actor',
#   'token': 3},
#  {'text': 'My friend Hector works as a samurai.',
#   'label': 'samurai',
#   'token': 3},
#  {'text': 'My cousin Denise, the politician, is a close friend of mine',
#   'label': 'politician',
#   'token': 3},
#  {'text': 'My cousin Maria, the author, is a close friend of mine',
#   'label': 'author',
#   'token': 3},
#  {'text': 'My mother Natalie, the anthropologist, went to the store.',
#   'label': 'anthropologist',
#   'token': 3},
#  {'text': 'My cousin Scott, the chemist, went to the store.',
#   'label': 'chemist',
#   'token': 3},
# ...
#   'token': 3},
#  {'text': 'My father Luis, the composer, is a close friend of mine',
#   'label': 'composer',
#   'token': 3},
#  {'text': 'My father Rebecca, the figure skater, attended my wedding last Wednesday.',
#   'label': 'figure skater',
#   'token': 3},
#  {'text': 'My father Jesus is tired from working as a association football manager all day',
#   'label': 'association football manager',
#   'token': 3},
#  {'text': 'My father Sharon dreams of becoming a entomologist.',
#   'label': 'entomologist',
#   'token': 3},
#  {'text': 'My father Tony, the architect, attended my wedding last Wednesday.',
#   'label': 'architect',
#   'token': 3},
#  {'text': 'My father Shannon dreams of becoming a film actor.',
#   'label': 'film actor',
#   'token': 3},
#  {'text': 'Natalie, the pianist, is a close friend of mine',
#   'label': 'pianist',
#   'token': 1},
#  {'text': 'This is a story about how Jacob works as a choreographer.',
#   'label': 'choreographer',
#   'token': 7},
#  {'text': 'My father Pedro, the geologist, is a close friend of mine',
#   'label': 'geologist',
#   'token': 3},
#  {'text': 'My father Liz, the racing driver, went to the store.',
#   'label': 'racing driver',
#   'token': 3},
#  {'text': 'My cousin Emma works as a playwright.',
#   'label': 'playwright',
#   'token': 3},
#  {'text': 'My father Antonio works as a tarento.',
#   'label': 'tarento',
#   'token': 3},
#  {'text': 'Peter, the photographer, went to the store.',
#   'label': 'photographer',
#   'token': 1},
#  {'text': 'My father Kyle, the seiyū, attended my wedding last Wednesday.',
#   'label': 'seiyū',
#   'token': 3},
#  {'text': 'My mother Elizabeth, the psychologist, is a close friend of mine',
#   'label': 'psychologist',
#   'token': 3},
#  {'text': 'My friend Wendy, the herpetologist, attended my wedding last Wednesday.',
#   'label': 'herpetologist',
#   'token': 3},
#  {'text': 'I met a friend named Tony dreams of becoming a boxer.',
#   'label': 'boxer',
#   'token': 6},
#  {'text': 'My father Christine, the opera singer, is a close friend of mine',
#   'label': 'opera singer',
#   'token': 3},
#  {'text': 'My cousin Josh, the film director, attended my wedding last Wednesday.',
#   'label': 'film director',
#   'token': 3},
#  {'text': 'My father Wendy, the theologian, attended my wedding last Wednesday.',
#   'label': 'theologian',
#   'token': 3},
#  {'text': 'My friend Anthony, the head coach, is a close friend of mine',
#   'label': 'head coach',
#   'token': 3},
#  {'text': 'This is a story about how Adriana is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 7},
#  {'text': 'My friend Matthew dreams of becoming a songwriter.',
#   'label': 'songwriter',
#   'token': 3},
#  {'text': 'My father Steven works as a opera singer.',
#   'label': 'opera singer',
#   'token': 3},
#  {'text': 'I met a friend named Adam, the monk, attended my wedding last Wednesday.',
#   'label': 'monk',
#   'token': 6},
#  {'text': 'My cousin Jenny, the military personnel, is a close friend of mine',
#   'label': 'military personnel',
#   'token': 3},
#  {'text': 'I met a friend named Francisco, the sociologist, went to the store.',
#   'label': 'sociologist',
#   'token': 6},
#  {'text': 'My mother Carmen dreams of becoming a trade unionist.',
#   'label': 'trade unionist',
#   'token': 3},
#  {'text': 'Isabel, the table tennis player, went to the store.',
#   'label': 'table tennis player',
#   'token': 1},
#  {'text': 'My father Danny, the cleric, went to the store.',
#   'label': 'cleric',
#   'token': 3},
#  {'text': 'My father Christine works as a athletics competitor.',
#   'label': 'athletics competitor',
#   'token': 3},
#  {'text': 'My mother Ana dreams of becoming a television presenter.',
#   'label': 'television presenter',
#   'token': 3},
#  {'text': 'My father Sandy, the translator, is a close friend of mine',
#   'label': 'translator',
#   'token': 3},
#  {'text': 'This is a story about how Diane is tired from working as a minister all day',
#   'label': 'minister',
#   'token': 7},
#  {'text': 'My friend Jay, the police officer, went to the store.',
#   'label': 'police officer',
#   'token': 3},
#  {'text': 'My father Mike, the figure skater, attended my wedding last Wednesday.',
#   'label': 'figure skater',
#   'token': 3},
#  {'text': 'My father Omar, the film director, attended my wedding last Wednesday.',
#   'label': 'film director',
#   'token': 3},
#  {'text': 'I met a friend named Jaime, the monk, went to the store.',
#   'label': 'monk',
#   'token': 6},
#  {'text': 'Raul dreams of becoming a actor.', 'label': 'actor', 'token': 1},
#  {'text': 'Monica, the music educator, went to the store.',
#   'label': 'music educator',
#   'token': 1},
#  {'text': 'My father Justin, the non-fiction writer, is a close friend of mine',
#   'label': 'non-fiction writer',
#   'token': 3},
#  {'text': 'I met a friend named Josh is tired from working as a singer-songwriter all day',
#   'label': 'singer-songwriter',
#   'token': 6},
#  {'text': 'I met a friend named Jaime, the explorer, attended my wedding last Wednesday.',
#   'label': 'explorer',
#   'token': 6},
#  {'text': 'I met a friend named Michael dreams of becoming a psychiatrist.',
#   'label': 'psychiatrist',
#   'token': 6},
#  {'text': 'Isabel is tired from working as a sport shooter all day',
#   'label': 'sport shooter',
#   'token': 1},
#  {'text': 'This is a story about how Wendy, the fencer, attended my wedding last Wednesday.',
#   'label': 'fencer',
#   'token': 7},
#  {'text': 'My friend Stephanie, the sculptor, went to the store.',
#   'label': 'sculptor',
#   'token': 3},
#  {'text': 'My friend Jason, the conductor, went to the store.',
#   'label': 'conductor',
#   'token': 3},
#  {'text': 'My father Christopher is tired from working as a voice actor all day',
#   'label': 'voice actor',
#   'token': 3},
#  {'text': 'My cousin Patrick dreams of becoming a catholic priest.',
#   'label': 'catholic priest',
#   'token': 3},
#  {'text': 'My father Debbie, the cinematographer, attended my wedding last Wednesday.',
#   'label': 'cinematographer',
#   'token': 3},
#  {'text': 'My cousin Tony dreams of becoming a boxer.',
#   'label': 'boxer',
#   'token': 3},
#  {'text': 'My mother Ashley, the police officer, is a close friend of mine',
#   'label': 'police officer',
#   'token': 3},
#  {'text': 'My cousin Peter, the computer scientist, is a close friend of mine',
#   'label': 'computer scientist',
#   'token': 3},
#  {'text': 'My mother Jasmine, the mangaka, went to the store.',
#   'label': 'mangaka',
#   'token': 3},
#  {'text': 'My cousin Liz works as a banker.', 'label': 'banker', 'token': 3},
#  {'text': 'My mother Christine dreams of becoming a badminton player.',
#   'label': 'badminton player',
#   'token': 3},
#  {'text': 'My cousin Carol dreams of becoming a actor.',
#   'label': 'actor',
#   'token': 3},
#  {'text': 'My father Lori is tired from working as a amateur wrestler all day',
#   'label': 'amateur wrestler',
#   'token': 3},
#  {'text': 'I met a friend named Judy dreams of becoming a chemist.',
#   'label': 'chemist',
#   'token': 6},
#  {'text': 'My cousin Bill dreams of becoming a publisher.',
#   'label': 'publisher',
#   'token': 3},
#  {'text': 'This is a story about how Mike dreams of becoming a music educator.',
#   'label': 'music educator',
#   'token': 7},
#  {'text': 'Jasmine, the painter, attended my wedding last Wednesday.',
#   'label': 'painter',
#   'token': 1},
#  {'text': 'My cousin Raul works as a banker.', 'label': 'banker', 'token': 3},
#  {'text': 'This is a story about how Michael dreams of becoming a association football referee.',
#   'label': 'association football referee',
#   'token': 7},
#  {'text': 'This is a story about how Angela dreams of becoming a choreographer.',
#   'label': 'choreographer',
#   'token': 7},
#  {'text': 'Nick, the teacher, went to the store.',
#   'label': 'teacher',
#   'token': 1},
#  {'text': 'My friend Jenny, the theatre director, is a close friend of mine',
#   'label': 'theatre director',
#   'token': 3},
#  {'text': 'My cousin Thomas dreams of becoming a missionary.',
#   'label': 'missionary',
#   'token': 3},
#  {'text': 'This is a story about how Jaime dreams of becoming a monk.',
#   'label': 'monk',
#   'token': 7},
#  {'text': 'My cousin Andrea, the beauty pageant contestant, is a close friend of mine',
#   'label': 'beauty pageant contestant',
#   'token': 3},
#  {'text': 'Alicia dreams of becoming a conductor.',
#   'label': 'conductor',
#   'token': 1},
#  {'text': 'My cousin Jacob, the artist, attended my wedding last Wednesday.',
#   'label': 'artist',
#   'token': 3},
#  {'text': 'My cousin Danielle dreams of becoming a sociologist.',
#   'label': 'sociologist',
#   'token': 3},
#  {'text': 'My father Jaime dreams of becoming a golfer.',
#   'label': 'golfer',
#   'token': 3},
#  {'text': 'My mother Megan, the singer, is a close friend of mine',
#   'label': 'singer',
#   'token': 3},
#  {'text': 'I met a friend named Gary, the screenwriter, went to the store.',
#   'label': 'screenwriter',
#   'token': 6},
#  {'text': 'My cousin Matt is tired from working as a artist all day',
#   'label': 'artist',
#   'token': 3},
#  {'text': 'My friend Eduardo is tired from working as a military personnel all day',
#   'label': 'military personnel',
#   'token': 3},
#  {'text': 'My friend Jason dreams of becoming a catholic priest.',
#   'label': 'catholic priest',
#   'token': 3},
#  {'text': 'I met a friend named Claudia, the opera singer, attended my wedding last Wednesday.',
#   'label': 'opera singer',
#   'token': 6},
#  {'text': 'This is a story about how Greg dreams of becoming a yachtmaster.',
#   'label': 'yachtmaster',
#   'token': 7},
#  {'text': 'Mary, the rugby union player, is a close friend of mine',
#   'label': 'rugby union player',
#   'token': 1},
#  {'text': 'My father Lori, the record producer, is a close friend of mine',
#   'label': 'record producer',
#   'token': 3},
#  {'text': 'Jose, the head coach, attended my wedding last Wednesday.',
#   'label': 'head coach',
#   'token': 1},
#  {'text': 'My friend Liz, the sculptor, is a close friend of mine',
#   'label': 'sculptor',
#   'token': 3},
#  {'text': 'My friend Sergio, the chess player, went to the store.',
#   'label': 'chess player',
#   'token': 3},
#  {'text': 'Jorge is tired from working as a diplomat all day',
#   'label': 'diplomat',
#   'token': 1},
#  {'text': 'Jim, the soldier, attended my wedding last Wednesday.',
#   'label': 'soldier',
#   'token': 1},
#  {'text': 'My mother Tiffany dreams of becoming a sociologist.',
#   'label': 'sociologist',
#   'token': 3},
#  {'text': 'My friend Veronica works as a music educator.',
#   'label': 'music educator',
#   'token': 3},
#  {'text': 'This is a story about how Aaron, the conductor, went to the store.',
#   'label': 'conductor',
#   'token': 7},
#  {'text': 'This is a story about how Kelly, the beauty pageant contestant, attended my wedding last Wednesday.',
#   'label': 'beauty pageant contestant',
#   'token': 7},
#  {'text': 'Tyler, the fencer, attended my wedding last Wednesday.',
#   'label': 'fencer',
#   'token': 1},
#  {'text': 'My friend Christopher, the motorcycle racer, is a close friend of mine',
#   'label': 'motorcycle racer',
#   'token': 3},
#  {'text': 'My friend Alejandro, the police officer, is a close friend of mine',
#   'label': 'police officer',
#   'token': 3},
#  {'text': 'My friend Scott works as a journalist.',
#   'label': 'journalist',
#   'token': 3},
#  {'text': 'My cousin Ricardo works as a guitarist.',
#   'label': 'guitarist',
#   'token': 3},
#  {'text': 'My cousin Justin is tired from working as a farmer all day',
#   'label': 'farmer',
#   'token': 3},
#  {'text': "My mother Alejandro, the children's writer, attended my wedding last Wednesday.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'My friend Diane is tired from working as a head coach all day',
#   'label': 'head coach',
#   'token': 3},
#  {'text': 'My cousin Victoria works as a art historian.',
#   'label': 'art historian',
#   'token': 3},
#  {'text': 'My cousin Brandon is tired from working as a amateur wrestler all day',
#   'label': 'amateur wrestler',
#   'token': 3},
#  {'text': 'My father George works as a zoologist.',
#   'label': 'zoologist',
#   'token': 3},
#  {'text': 'This is a story about how Diana, the film actor, is a close friend of mine',
#   'label': 'film actor',
#   'token': 7},
#  {'text': 'I met a friend named Lori is tired from working as a diplomat all day',
#   'label': 'diplomat',
#   'token': 6},
#  {'text': 'I met a friend named Tyler is tired from working as a diplomat all day',
#   'label': 'diplomat',
#   'token': 6},
#  {'text': 'My father William, the herpetologist, is a close friend of mine',
#   'label': 'herpetologist',
#   'token': 3},
#  {'text': 'My friend Kelly, the guitarist, went to the store.',
#   'label': 'guitarist',
#   'token': 3},
#  {'text': 'Kelly, the economist, is a close friend of mine',
#   'label': 'economist',
#   'token': 1},
#  {'text': 'My father Vanessa, the announcer, attended my wedding last Wednesday.',
#   'label': 'announcer',
#   'token': 3},
#  {'text': 'This is a story about how Lauren, the jazz musician, attended my wedding last Wednesday.',
#   'label': 'jazz musician',
#   'token': 7},
#  {'text': 'Amanda, the military personnel, went to the store.',
#   'label': 'military personnel',
#   'token': 1},
#  {'text': 'This is a story about how Heather works as a table tennis player.',
#   'label': 'table tennis player',
#   'token': 7},
#  {'text': 'Patrick, the physician, is a close friend of mine',
#   'label': 'physician',
#   'token': 1},
#  {'text': 'This is a story about how Lori dreams of becoming a diplomat.',
#   'label': 'diplomat',
#   'token': 7},
#  {'text': 'This is a story about how Danny, the university teacher, attended my wedding last Wednesday.',
#   'label': 'university teacher',
#   'token': 7},
#  {'text': 'My cousin Ana, the lawyer, went to the store.',
#   'label': 'lawyer',
#   'token': 3},
#  {'text': 'I met a friend named Danielle works as a table tennis player.',
#   'label': 'table tennis player',
#   'token': 6},
#  {'text': 'I met a friend named Vanessa is tired from working as a model all day',
#   'label': 'model',
#   'token': 6},
#  {'text': 'My friend Jay, the record producer, went to the store.',
#   'label': 'record producer',
#   'token': 3},
#  {'text': 'My cousin Tim works as a physician.',
#   'label': 'physician',
#   'token': 3},
#  {'text': 'My friend Jenny, the singer-songwriter, is a close friend of mine',
#   'label': 'singer-songwriter',
#   'token': 3},
#  {'text': 'My mother Mary, the rugby union player, attended my wedding last Wednesday.',
#   'label': 'rugby union player',
#   'token': 3},
#  {'text': 'I met a friend named Mike is tired from working as a visual artist all day',
#   'label': 'visual artist',
#   'token': 6},
#  {'text': 'My cousin Kyle dreams of becoming a fencer.',
#   'label': 'fencer',
#   'token': 3},
#  {'text': "My father Amy, the children's writer, is a close friend of mine",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'My mother Silvia dreams of becoming a officer.',
#   'label': 'officer',
#   'token': 3},
#  {'text': 'My mother Jonathan is tired from working as a explorer all day',
#   'label': 'explorer',
#   'token': 3},
#  {'text': 'My father Stephanie dreams of becoming a police officer.',
#   'label': 'police officer',
#   'token': 3},
#  {'text': 'This is a story about how Peter dreams of becoming a banker.',
#   'label': 'banker',
#   'token': 7},
#  {'text': 'My cousin Amanda is tired from working as a psychologist all day',
#   'label': 'psychologist',
#   'token': 3},
#  {'text': 'Mike, the officer, attended my wedding last Wednesday.',
#   'label': 'officer',
#   'token': 1},
#  {'text': 'My father Steve, the minister, is a close friend of mine',
#   'label': 'minister',
#   'token': 3},
#  {'text': "My cousin Mary dreams of becoming a children's writer.",
#   'label': "children's writer",
#   'token': 3},
#  {'text': 'Rafael is tired from working as a cleric all day',
#   'label': 'cleric',
#   'token': 1},
#  {'text': 'My mother Tom, the teacher, went to the store.',
#   'label': 'teacher',
#   'token': 3},
#  {'text': 'My mother Cindy, the tennis player, is a close friend of mine',
#   'label': 'tennis player',
#   'token': 3},
#  {'text': 'Megan dreams of becoming a av idol.',
#   'label': 'av idol',
#   'token': 1},
#  {'text': 'This is a story about how Eduardo, the singer-songwriter, attended my wedding last Wednesday.',
#   'label': 'singer-songwriter',
#   'token': 7},
#  ...]

# %%
occupations = {sample['label'] for sample in samples}
candidates_idx = set()
for occupation in occupations:
    ids = tokenizer(occupation, add_special_tokens=False)
    candidates_idx |= set(ids.input_ids)
len(occupations), len(candidates_idx)
# Out:
# (150, 190)

# %%
import torch
from torch.utils import data
from tqdm.auto import tqdm

for sample in samples:
    if 'prediction' in sample:
        del sample['prediction']

loader = data.DataLoader(samples, batch_size=64)

predictions, precomputed = [], []
for batch in tqdm(loader):
    texts = [
        text.replace(occupation, '[MASK]')
        for text, occupation in zip(batch['text'], batch['label'])
    ]
    inputs = tokenizer(texts, return_tensors='pt', padding='longest').to(device)

    with torch.inference_mode():
        outputs = model(**inputs, return_dict=True, output_hidden_states=True)
        
    batch_idx = range(len(texts))
    mask_idx = [
        ids.eq(tokenizer.mask_token_id).int().argmax().item()
        for ids in inputs.input_ids
    ]
    logits = outputs['logits'][batch_idx, mask_idx]
    logits[:, sorted(candidates_idx)] *= 10000
    ids = logits.argmax(dim=-1)
    tokens = tokenizer.batch_decode(ids)
    predictions.extend(tokens)

    reps = outputs.hidden_states[-1][batch_idx, batch['token']]
    precomputed.append(reps)
precomputed = torch.cat(precomputed)

for sample, pred in zip(samples, predictions):
    sample['prediction'] = pred
# Out:
#   0%|          | 0/7813 [00:00<?, ?it/s]

# %%
p = set()
for pred in predictions:
    p |= {pred}
len(p)
p
# Out:
# {'actor',
#  'artist',
#  'author',
#  'catholic',
#  'director',
#  'driver',
#  'editor',
#  'farmer',
#  'journalist',
#  'judge',
#  'lawyer',
#  'manager',
#  'minister',
#  'model',
#  'painter',
#  'photographer',
#  'pianist',
#  'player',
#  'poet',
#  'politician',
#  'priest',
#  'psychologist',
#  'rabbi',
#  'scientist',
#  'singer',
#  'soldier',
#  'teacher',
#  'writer'}

# %% [markdown]
# # Train probe

# %%
EPOCHS = 5
BATCH_SIZE = 32
LR = 1e-3
PATIENCE = 4
HOLD_OUT = .5
EXCLUDE = .01

# %%
from torch.utils import data

class Dataset(data.Dataset):
    
    def __init__(self, samples, precomputed):
        self.samples = samples
        self.precomputed = precomputed
        
        indexer = {'unk': 0}
        for sample in samples:
            label = sample['label']
            if label not in indexer:
                indexer[label] = len(indexer)
        self.indexer = indexer
        
    def __getitem__(self, index):
        sample = self.samples[index]
        rep = self.precomputed[index]
        return rep, self.indexer.get(sample['prediction'], 0)

    def __len__(self):
        return len(self.samples)

dataset = Dataset(samples, precomputed)

exclude_size = int(EXCLUDE * len(dataset))
val_size = int(HOLD_OUT * len(dataset))
train_size = len(dataset) - val_size - exclude_size
train, val, exclude = data.random_split(dataset, (train_size, val_size, exclude_size))

train_loader = data.DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)
val_loader = data.DataLoader(val, batch_size=BATCH_SIZE)

# %%
import torch
from torch import nn, optim
from tqdm.auto import tqdm

probe = nn.Sequential(
    nn.Linear(768, 768),
    nn.LeakyReLU(),
    nn.Linear(768, len(dataset.indexer)),
).to(device)
optimizer = optim.AdamW(probe.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

progress = tqdm(range(EPOCHS), desc='train probe')
best, bad, state_dict = float('inf'), 0, None
for epoch in progress:
    train_loss = 0.
    for reps, targets in train_loader:
        predictions = probe(reps)
        loss = criterion(predictions, targets.to(device))
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        train_loss += loss.item()
    train_loss /= len(train_loader)

    val_loss = 0.
    with torch.inference_mode():
        for reps, targets in val_loader:
            predictions = probe(reps)
            loss = criterion(predictions, targets.to(device))
            val_loss += loss.item()
    val_loss /= len(val_loader)

    progress.set_description(f'train probe (train={train_loss:.3f}, val={val_loss:.3f})')

    if val_loss < best:
        state_dict = probe.state_dict()
        best = val_loss
        bad = 0
    else:
        bad += 1

    if bad > PATIENCE:
        probe.load_state_dict(state_dict)
        break
# Out:
# train probe:   0%|          | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-08eacdd3591c> in <module>
#      18         predictions = probe(reps)
#      19         loss = criterion(predictions, targets.to(device))
# ---> 20         loss.backward()
#      21         optimizer.step()
#      22         optimizer.zero_grad()
#
# /raid/lingo/dez/pyenv/versions/3.8.10/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /raid/lingo/dez/pyenv/versions/3.8.10/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
from torch.utils import data
from tqdm.auto import tqdm

@torch.inference_mode()
def test(dataset):
    loader = data.DataLoader(dataset, batch_size=BATCH_SIZE)
    correct = 0
    for reps, targets in tqdm(loader):
        predictions = probe(reps).argmax(dim=-1)
        correct += predictions.view(len(reps)).eq(targets.to(device).view(len(reps))).sum()
    return correct / len(dataset)

print(test(val))
print(test(exclude))
# Out:
#   0%|          | 0/7813 [00:00<?, ?it/s]
# ['unk', 'priest', 'teacher', 'photographer', 'unk', 'author', 'photographer', 'teacher', 'photographer', 'teacher', 'lawyer', 'unk', 'lawyer', 'writer', 'photographer', 'farmer', 'lawyer', 'teacher', 'teacher', 'lawyer', 'lawyer', 'singer', 'priest', 'photographer', 'singer', 'unk', 'lawyer', 'lawyer', 'teacher', 'photographer', 'photographer', 'lawyer']
# 0.0
#   0%|          | 0/157 [00:00<?, ?it/s]
# ['priest', 'farmer', 'unk', 'lawyer', 'lawyer', 'lawyer', 'author', 'photographer', 'lawyer', 'singer', 'unk', 'author', 'lawyer', 'lawyer', 'lawyer', 'teacher', 'singer', 'priest', 'teacher', 'teacher', 'photographer', 'teacher', 'unk', 'author', 'singer', 'lawyer', 'priest', 'singer', 'model', 'photographer', 'author', 'singer']
# 0.0

# %%
import torch

@torch.inference_mode()
def predict(text, tokens=[1]):
    inputs = tokenizer(text, return_tensors='pt', padding='longest').to(device)
    print(tokenizer.convert_ids_to_tokens(inputs.input_ids.squeeze().tolist()))
    outputs = model(**inputs, return_dict=True, output_hidden_states=True)
    reps = outputs.hidden_states[-1][:, tokens].mean(dim=1)
    chosens = probe(reps).topk(k=3, dim=-1).indices.squeeze().tolist()
    unindexer = {idx: label for label, idx in dataset.indexer.items()}
    return [unindexer[chosen] for chosen in chosens]
predict('A person works in a hospital and uses a scalpel. He is a [MASK]', tokens=[2])
# Out:
# ['[CLS]', 'a', 'person', 'works', 'in', 'a', 'hospital', 'and', 'uses', 'a', 'scalp', '##el', '.', 'he', 'is', 'a', '[MASK]', '[SEP]']
# ['teacher', 'lawyer', 'priest']

# %%
samples[:10]
# Out:
# [{'text': 'Carlos, the missionary, attended my wedding last Wednesday.',
#   'label': 'missionary',
#   'token': 1,
#   'prediction': 'priest'},
#  {'text': 'My mother Christine, the rugby union player, went to the store.',
#   'label': 'rugby union player',
#   'token': 3,
#   'prediction': 'manager'},
#  {'text': 'My friend Lori is tired from working as a radio personality all day',
#   'label': 'radio personality',
#   'token': 3,
#   'prediction': 'model'},
#  {'text': 'My father Josh dreams of becoming a television actor.',
#   'label': 'television actor',
#   'token': 3,
#   'prediction': 'lawyer'},
#  {'text': 'My mother Sharon, the stage actor, attended my wedding last Wednesday.',
#   'label': 'stage actor',
#   'token': 3,
#   'prediction': 'singer'},
#  {'text': 'My mother Julia, the diplomat, attended my wedding last Wednesday.',
#   'label': 'diplomat',
#   'token': 3,
#   'prediction': 'singer'},
#  {'text': 'My friend Paula is tired from working as a entrepreneur all day',
#   'label': 'entrepreneur',
#   'token': 3,
#   'prediction': 'model'},
#  {'text': 'My father Christina is tired from working as a sport shooter all day',
#   'label': 'sport shooter',
#   'token': 3,
#   'prediction': 'farmer'},
#  {'text': "My mother Scott works as a children's writer.",
#   'label': "children's writer",
#   'token': 3,
#   'prediction': 'teacher'},
#  {'text': 'I met a friend named Jaime, the farmer, is a close friend of mine',
#   'label': 'farmer',
#   'token': 6,
#   'prediction': 'singer'}]
